# %%
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from langchain_openai import OpenAIEmbeddings
import chromadb
from decouple import config
import chromadb.utils.embedding_functions as embedding_functions
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                api_key=config("OPENAI_API_KEY"),
                model_name="text-embedding-3-small"
            )
chroma_client = chromadb.HttpClient(host=config('CHROMA_HOST'), port=8000)

                        
collection = chroma_client.get_or_create_collection(name="investor_lookup", embedding_function=openai_ef)

# %%
import uuid
import requests
from decouple import config
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_pinecone import PineconeVectorStore
from langsmith import traceable
from pinecone import Pinecone
from pyairtable import Api
from django.db import models, transaction
from langchain_chroma import Chroma

from submind.prompts.prompts import TOOL_RESULT_PROMPT


def get_fundraises():
    pass


def get_industry():
    pass


# can we turn a plaintext query into a structured airtable query? Maybe for now, just create a fulltext field and dump in pinecone?
schema = {

}


def get_airtable_schema(base_id, api_key):
    url = f'https://api.airtable.com/v0/meta/bases/{base_id}/tables'
    headers = {
        'Authorization': f'Bearer {api_key}',
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()


# Function to map Airtable field types to Django field types
def map_field_type(airtable_type):
    mapping = {
        'singleLineText': 'models.CharField(max_length=255)',
        'multilineText': 'models.TextField()',
        'richText': 'models.TextField()',
        'number': 'models.FloatField()',
        'checkbox': 'models.BooleanField()',
        'date': 'models.DateField()',
        'dateTime': 'models.DateTimeField()',
        'currency': 'models.DecimalField(max_digits=10, decimal_places=2)',
        'percent': 'models.FloatField()',
        'singleSelect': 'models.CharField(max_length=255)',
        'multipleSelects': 'models.JSONField()',
        'attachment': 'models.JSONField()',
        'formula': 'models.CharField(max_length=255)',
        'rollup': 'models.CharField(max_length=255)',
        'createdTime': 'models.DateTimeField(auto_now_add=True)',
        'lastModifiedTime': 'models.DateTimeField(auto_now=True)',
        'autoNumber': 'models.AutoField()',
    }
    return mapping.get(airtable_type, 'models.CharField(max_length=255)')


# Function to generate Django model
def generate_django_model(table):
    model_name = table['name'].replace(' ', '')
    fields = table['fields']

    model = f'class {model_name}(models.Model):\n'
    for field in fields:
        field_name = field['name'].replace(' ', '_').lower()
        field_type = map_field_type(field['type'])
        model += f'    {field_name} = {field_type}\n'

    return model


# Function to fetch data from Airtable
def fetch_airtable_data(table_name, base_id, api_key):
    url = f"{config('AIRTABLE_API_URL')}/{base_id}/{table_name}"
    headers = {
        'Authorization': f'Bearer {api_key}',
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()['records']


# Function to populate Django database
def populate_django_db(table_name, model, base_id, api_key):
    data = fetch_airtable_data(table_name, base_id, api_key)
    ModelClass = globals()[model]
    with transaction.atomic():
        for record in data:
            fields = record['fields']
            model_instance = ModelClass()
            for field_name, value in fields.items():
                django_field_name = field_name.replace(' ', '_').lower()
                setattr(model_instance, django_field_name, value)
            model_instance.save()

def get_all_records():
    api = Api(config('PRELO_AIRTABLE_API_KEY'))
    table = api.table(config('PRELO_BASE_ID'), config('PRELO_TABLE_ID'))
    records = table.all()
    return records

def get_no_warm_investor_records():
    api = Api(config('PRELO_AIRTABLE_API_KEY'))
    table = api.table(config('PRELO_BASE_ID'), config('PRELO_NO_WARM_TABLE_ID'))
    records = table.all()
    return records

def get_angel_records():
    api = Api(config('PRELO_AIRTABLE_API_KEY'))
    table = api.table(config('PRELO_BASE_ID'), config('PRELO_ANGEL_TABLE_ID'))
    records = table.all()
    return records



def format_records(records):
    formatted_strings = []
    for record in records:
        formatted_record = ", ".join(f"{key}: {value}" for key, value in record.items())
        formatted_strings.append(formatted_record)
    return formatted_strings


def load_record_vectors(records):
    metadatas = []
    ids = []
    chunks_to_save = []
    for record in records:
        formatted_record = ", ".join(f"{key}: {value}" for key, value in record['fields'].items())
        id = str(uuid.uuid4())
        metadata = {
            "airtable_id": record['id'],
            "created_at": record['createdTime'],
            "founders": record['fields'].get("Founders", ""),
            "stage": record['fields'].get("Funding Stage", ""),
            "industry": record['fields'].get("Industry", ""),
            "funding_amount": record['fields'].get("Last Funding (USD)", ""),
        }

        chunks_to_save.append(formatted_record)
        metadatas.append(metadata)
        ids.append(id)

    collection.add(documents=chunks_to_save, metadatas=metadatas, ids=ids)

def load_angel_investor_records(records):
    metadatas = []
    ids = []
    chunks_to_save = []
    for record in records:
        formatted_record = ", ".join(f"{key}: {value}" for key, value in record['fields'].items())
        id = str(uuid.uuid4())
        metadata = {
            "airtable_id": record['id'],
            "created_at": record['createdTime'],
            "investor": record['fields'].get("Investor (VC or Angel)", ""),
            "contact_name": record['fields'].get("Contact Name", ""),
            "industry": str(record['fields'].get("Preferred Sectors", "")),
            "funding_stage": str(record['fields'].get("Preferred Investment Size", "")),
            "funding_amount": record['fields'].get("Last Funding (USD)", ""),
        }

        chunks_to_save.append(formatted_record)
        metadatas.append(metadata)
        ids.append(id)
    collection.add(documents=chunks_to_save, metadatas=metadatas, ids=ids)



def load_no_warm_intro_investor_records(records):
    metadatas = []
    ids = []
    chunks_to_save = []
    for record in records:
        formatted_record = ", ".join(f"{key}: {value}" for key, value in record['fields'].items())
        record_id = str(uuid.uuid4())
        metadata = {
            "airtable_id": record['id'],
            "created_at": record['createdTime'],
            "investor": record['fields'].get("Investor (VC or Angel)", ""),
            "contact_name": record['fields'].get("Contact Name", ""),
            "industry": str(record['fields'].get("Industry", "")),
            "check_size": str(record['fields'].get("Check Size $", "")),
            "funding_stage": str(record['fields'].get("Funding Stage", "")),
            "geography": str(record['fields'].get("Geography", "")),
        }
        
        print(f'record: {formatted_record}')
        chunks_to_save.append(formatted_record)
        metadatas.append(metadata)
        ids.append(record_id)

        collection.add(documents=[formatted_record], metadatas=[metadata], ids=[record_id])
        print("added record")

    


TOOL_DESCRIPTION = "This tool allows you to get information about startups, their founders, and their fundraising efforts"


@traceable
def query_records(query, previous_results=None):
    embeddings = OpenAIEmbeddings(
                            model="text-embedding-3-small",
                            openai_api_key=config("OPENAI_API_KEY"),
                            openai_api_base=config('OPENAI_API_BASE'),
                            headers={
                                "Helicone-Auth": f"Bearer {config('HELICONE_API_KEY')}"
                            })
    langchain_chroma = Chroma(
        client=chroma_client,
        collection_name="investor_lookup",
        embedding_function=embeddings,
    )

   
    matched = langchain_chroma.similarity_search(query, k=5)
    docs = "\n\n".join(doc.page_content for doc in matched)
    model = ChatOpenAI(model="gpt-4-turbo", openai_api_key=config("OPENAI_API_KEY"))
    prompt = ChatPromptTemplate.from_template(TOOL_RESULT_PROMPT)
    chain = prompt | model | StrOutputParser()
    combined_query = f"{previous_results}\n\n{query}" if previous_results else query
    response = chain.invoke({
        "query": combined_query,
        "tool_description": TOOL_DESCRIPTION,
        "tool_output": docs
    })
    print(response)
    return response

# %%
angel_records = get_angel_records()

# %%
no_warm_intro_records = get_no_warm_investor_records()

# %%
query_records("angel investor in the united states that invests in healthcare")
# Out:
# Here is the information about angel investors in the United States that invest in healthcare, formatted for clarity and ease of comparison:
#
# 1. **US Angel Investors**
#    - **Location:** Palo Alto, CA
#    - **Contact Name:** John Ricci
#    - **Title:** Founder & President
#    - **Description:** A group that provides counsel and capital to startups in various industries including healthcare and medical devices.
#    - **Preferred Sectors:** Software
#    - **Type:** Angel Group
#    - **Website:** Not provided
#
# 2. **Venture-med**
#    - **Location:** Orinda, CA
#    - **Website:** [www.venture-med.com](http://www.venture-med.com)
#    - **Phone Number:** +1 (858) 369-3888
#    - **Description:** An organization of accredited investors focused on healthcare startups, offering seed funding and mentorship.
#    - **Preferred Sectors:** Commercial Services, Software
#    - **Type:** Angel Group
#
# 3. **Health Wildcatters**
#    - **Location:** Dallas, TX
#    - **Website:** [www.healthwildcatters.com](http://www.healthwildcatters.com)
#    - **Contact Name:** Hubert Zajicek
#    - **Phone Number:** +1 (610) 934-2222
#    - **Title:** Co-Founder, Partner, Executive Director & CEO
#    - **Description:** A seed accelerator supporting healthcare startups in digital health, medical devices, and diagnostics.
#    - **Preferred Sectors:** Software
#    - **Preferred Investment Size:** Early Stage VC, Seed Round
#    - **Preferred Transaction Sizes:** 0.03
#    - **Type:** Accelerator/Incubator
#
# 4. **HealthTech Capital**
#    - **Location:** Palo Alto, CA
#    - **Website:** [www.healthtechcapital.com](http://www.healthtechcapital.com)
#    - **Contact Name:** Kathleen LaPorte
#    - **Title:** Co-Founder & Member
#    - **Description:** Invests in health-tech startups, assisting in technical and market feasibility, business development, and additional financing.
#    - **Preferred Sectors:** Software
#    - **Preferred Investment Size:** Accelerator/Incubator, Early Stage VC
#    - **Preferred Transaction Sizes:** 2
#    - **Type:** Angel Group
#
# 5. **StartUp Health**
#    - **Location:** New York, NY
#    - **Website:** [www.startuphealth.com](http://www.startuphealth.com)
#    - **Contact Name:** Steven H. Krein
#    - **Title:** Co-Founder, Chairman & CEO
#    - **Description:** An incubator that supports digital health company entrepreneurs with education and resources.
#    - **Preferred Sectors:** Software
#    - **Preferred Investment Size:** Early Stage VC, Seed Round
#    - **Type:** Accelerator/Incubator
#
# These investors and groups are potential resources for startups in the healthcare sector looking for capital, mentorship, and industry connections.
# 'Here is the information about angel investors in the United States that invest in healthcare, formatted for clarity and ease of comparison:\n\n1. **US Angel Investors**\n   - **Location:** Palo Alto, CA\n   - **Contact Name:** John Ricci\n   - **Title:** Founder & President\n   - **Description:** A group that provides counsel and capital to startups in various industries including healthcare and medical devices.\n   - **Preferred Sectors:** Software\n   - **Type:** Angel Group\n   - **Website:** Not provided\n\n2. **Venture-med**\n   - **Location:** Orinda, CA\n   - **Website:** [www.venture-med.com](http://www.venture-med.com)\n   - **Phone Number:** +1 (858) 369-3888\n   - **Description:** An organization of accredited investors focused on healthcare startups, offering seed funding and mentorship.\n   - **Preferred Sectors:** Commercial Services, Software\n   - **Type:** Angel Group\n\n3. **Health Wildcatters**\n   - **Location:** Dallas, TX\n   - **Website:** [www.healthwildcatters.com](http://www.healthwildcatters.com)\n   - **Contact Name:** Hubert Zajicek\n   - **Phone Number:** +1 (610) 934-2222\n   - **Title:** Co-Founder, Partner, Executive Director & CEO\n   - **Description:** A seed accelerator supporting healthcare startups in digital health, medical devices, and diagnostics.\n   - **Preferred Sectors:** Software\n   - **Preferred Investment Size:** Early Stage VC, Seed Round\n   - **Preferred Transaction Sizes:** 0.03\n   - **Type:** Accelerator/Incubator\n\n4. **HealthTech Capital**\n   - **Location:** Palo Alto, CA\n   - **Website:** [www.healthtechcapital.com](http://www.healthtechcapital.com)\n   - **Contact Name:** Kathleen LaPorte\n   - **Title:** Co-Founder & Member\n   - **Description:** Invests in health-tech startups, assisting in technical and market feasibility, business development, and additional financing.\n   - **Preferred Sectors:** Software\n   - **Preferred Investment Size:** Accelerator/Incubator, Early Stage VC\n   - **Preferred Transaction Sizes:** 2\n   - **Type:** Angel Group\n\n5. **StartUp Health**\n   - **Location:** New York, NY\n   - **Website:** [www.startuphealth.com](http://www.startuphealth.com)\n   - **Contact Name:** Steven H. Krein\n   - **Title:** Co-Founder, Chairman & CEO\n   - **Description:** An incubator that supports digital health company entrepreneurs with education and resources.\n   - **Preferred Sectors:** Software\n   - **Preferred Investment Size:** Early Stage VC, Seed Round\n   - **Type:** Accelerator/Incubator\n\nThese investors and groups are potential resources for startups in the healthcare sector looking for capital, mentorship, and industry connections.'

# %%
# load_angel_investor_records(angel_records)
# load_no_warm_intro_investor_records(no_warm_intro_records) - breaks on empty record at end
# Out:
# record: Contact Name: Alex Kopelyan, Investor (VC or Angel): IndieBio (SOSV), Industry: ['Agritech', 'BioTech', 'CleanTech', 'Deep tech', 'Digital Health', 'Foodtech', 'Sustainable Materials', 'MedTech & Healthcare', 'FemTech', 'Love crazy ideas', 'Mental Health'], Check Size $: 250,000, Funding Stage: ['Pre-seed', 'Idea/first check'], Do you lead rounds?: ['Accelerator'], # of cold outreach investments made:: Don't know the number, but a good percent of our 150 investments, Additional notes for founders:: We invest in cohorts, up to 15 companies roughly twice per year. We do investments beyond the accelerator into seed, A, and beyond. However that is only for accelerator alum.
# added record
# record: Contact Name: Mark Pearson, Investor (VC or Angel): Fuel Ventures, Industry: ['Adtech', 'AI/ML', 'AR/VR', 'B2B', 'B2C', 'Beauty', 'Beauty & wellness', 'CleanTech', 'Consumer', 'Cybersecurity', 'Digital Health', 'Digital health', 'DTC', 'E-commerce', 'Edtech', 'Enterprise Software', 'Fintech', 'Wellness', 'We work with people without college degrees! Let me know if you have one or not :)', 'SaaS', 'Retail Tech', 'Marketplace', 'FemTech', 'Gaming', 'InsurTech', 'Generalist', 'No code', 'Legal Tech', 'Industry Agnostic', 'Martech'], Check Size $: £150 to £5m Pre-seed to A stage, Funding Stage: ['Pre-seed', 'Seed', 'Series A', 'Idea/first check'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 30, Geography: UK & Europe , Additional notes for founders:: Submit here https://fuel.ventures/contact/entrepreneur-application/
# added record
# record: Contact Name: Sab (Sabareesh Kornipalli), Investor (VC or Angel): linkedin.com/in/sabareesh-kornipalli, Industry: ['Aerospace', 'Adtech', 'AI/ML', 'All deep tech!', 'BioTech', 'CleanTech', 'Cybersecurity', 'Deep tech', 'Digital Health', 'Edtech', 'Fintech', 'Foodtech', 'MedTech & Healthcare', 'Mental Health', 'SaaS', 'Social impact'], Check Size $: 25000 - 100000, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: 3, Geography: US, India
# added record
# record: Contact Name: Kookai Chaimahawong, Investor (VC or Angel): Pangaea Ventures, Industry: ['Agritech', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'CleanTech', 'Foodtech', 'Hard Tech & Manufacturing', 'Materials'], Check Size $: $3M - $5M, Funding Stage: ['Series A', 'Series B', 'Series C'], # of cold outreach investments made:: 5
# added record
# record: Contact Name: Alex Freed, Investor (VC or Angel): Schematic Ventures, Industry: ['Aerospace', 'Agritech', 'E-commerce', 'Hard Tech & Manufacturing', 'Marketplace', 'Renewable Energy', 'Supply Chain', 'SaaS', 'Transport'], Check Size $: $1M - $1.5M, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], Additional notes for founders:: https://www.schematicventures.com/
# added record
# record: Contact Name: Janine Sickmeyer, Investor (VC or Angel): Let's Start Up Ventures (Angel Investor), Industry: ['B2B', 'Enterprise Software', 'SaaS', 'Martech', 'Mental Health'], Check Size $: $10K-$50K, Funding Stage: ['Pre-seed', 'Idea/first check'], Do you lead rounds?: ['co-lead'], # of cold outreach investments made:: 2
# added record
# record: Contact Name: Zann Ali, Investor (VC or Angel): 2048 Ventures, Industry: ['Generalist'], Check Size $: $300-$600K, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Kenn So, Investor (VC or Angel): Shasta Ventures, Industry: ['AI/ML', 'B2B', 'Enterprise Software', 'Fintech', 'Growthtech', 'SaaS'], Check Size $: $250,000 - $10,000,000, Funding Stage: ['Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Mark Mason, Investor (VC or Angel): SWaN & Legend Venture Partners, Industry: ['B2C', 'E-commerce', 'DTC', 'Consumer', 'Gaming', 'Marketplace', 'Media', 'Retail Tech'], Check Size $: $4M-10M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Kriti Lall, Investor (VC or Angel): Individual, Industry: ['BioTech', 'MedTech & Healthcare'], Check Size $: Any, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 1
# added record
# record: Contact Name: Tarik Abbas, Investor (VC or Angel): Saola Ventures, Industry: ['Agritech', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'CleanTech', 'E-commerce', 'DTC', 'Consumer', 'Fintech', 'Future of Work & Productivity', 'Gaming', 'Marketplace', 'Real Estate & Hospitality', 'Transport'], Check Size $: -, Funding Stage: ['Seed', 'Series A', 'Series B']
# added record
# record: Contact Name: Victoria Perweiler, Investor (VC or Angel): Digitalis Ventures, Industry: ['Digital Health', 'Mental Health', 'BioTech', 'FemTech'], Check Size $: 0.5m - 5m , Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['co-lead', 'or follow depending on the stage of the company', 'We lead rounds where we feel we are the best partner at the table and can add the most value to the company', 'but equally happy to co-invest alongside qualified leads'], # of cold outreach investments made:: 3, Additional notes for founders:: Digitalis invests in founders building solutions to complex problems in human and animal health.
# added record
# record: Contact Name: Sarah Vickery, Investor (VC or Angel): Loeb.nyc, Industry: ['B2C', 'Beauty', 'Wellness', 'E-commerce', 'DTC', 'Consumer', 'Fintech', 'InsurTech', 'Marketplace', 'Media', 'Mental Health'], Check Size $: $100K - $5M, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Brad Jenkins, Investor (VC or Angel): Seed Round Capital, Industry: ['B2B', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Enterprise Software', 'Fintech', 'Marketplace', 'SaaS', 'Legal Tech'], Check Size $: $25K - $50K, Funding Stage: ['Pre-seed'], # of cold outreach investments made:: 2, Additional notes for founders:: We make investments into pre-seed stage startups that have found initial traction and are generating revenue of at least $3k per month.
# added record
# record: Contact Name: John Prendergass, Investor (VC or Angel): Ben Franklin Technology Partners of Southeastern PA, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Hard Tech & Manufacturing', 'InsurTech', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS', 'Transport'], Check Size $: $50,000 - $1,000,000, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Geography: greater Philadelphia area, Additional notes for founders:: Focus on companies with a presence and plan to grow jobs in the greater Philadelphia area.
# added record
# record: Contact Name: Sri Muppidi, Investor (VC or Angel): Sierra Ventures, Industry: ['AI/ML', 'B2B', 'Cybersecurity', 'Digital Health', 'Enterprise Software', 'Future of Work & Productivity', 'Hard Tech & Manufacturing', 'No Code focus', 'SaaS'], Check Size $: 500K - 10M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Lucy Wang, Investor (VC or Angel): Divergent Capital/Individual, Industry: ['Aerospace', 'Agritech', 'AI/ML', 'BioTech', 'MedTech & Healthcare', 'CleanTech', 'Cybersecurity', 'Digital Health', 'Enterprise Software', 'Hard Tech & Manufacturing', 'Mental Health', 'Renewable Energy', 'Sustainable Materials', 'Transport'], Check Size $: $10K - $750K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 2, Additional notes for founders:: I invest in deeply technical founders commercializing new tech + scientific innovations
# added record
# record: Contact Name: Ashelë Woods, Investor (VC or Angel): Serena Ventures, Industry: ['Generalist'], Check Size $: up to $4M, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes'], Additional notes for founders:: Emails under 150 words with a deck (!!) are very welcome to ashele@serenaventures.com
# added record
# record: Contact Name: Pascal Unger, Investor (VC or Angel): Darling Ventures, Industry: ['Adtech', 'AI/ML', 'B2B', 'Blockchain & Crypto', 'Digital Health', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Hard Tech & Manufacturing', 'InsurTech', 'Legaltech', 'Marketplace', 'Real Estate & Hospitality', 'SaaS'], Check Size $: $250K - $500K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], Geography: Bay Area, Additional notes for founders:: Pre-Seed / Seed based in the Bay Area. First backers at the frontier of technical innovation. Please feel free to reach out! darlingventures.com
# added record
# record: Contact Name: Ryan Falvey, Investor (VC or Angel): Financial Venture Studio, Industry: ['Fintech', 'B2B', 'B2C', 'Blockchain & Crypto', 'InsurTech', 'Real Estate & Hospitality'], Check Size $: $100,000 - $200,000 initial checks (up to $1m total), Funding Stage: ['Pre-seed', 'Idea/first check', 'Seed'], Do you lead rounds?: ['No', 'I help founders find leads.', 'Accelerator'], # of cold outreach investments made:: ~20% of the portfolio
# added record
# record: Contact Name: Dan Carroll, Investor (VC or Angel): Individual Angel, Industry: ['Edtech'], Check Size $: $5-25k, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['I help founders find leads.'], Additional notes for founders:: Focused on K-12 edtech. More likely to help make connections than write a check.
# added record
# record: Contact Name: Paula-Kaye Richards, Investor (VC or Angel): Space Angels, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'Cybersecurity', 'Growthtech'], Check Size $: $250,000 to $1.5 million, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 5
# added record
# record: Contact Name: Kelsey Rudin, Investor (VC or Angel): Overview, Industry: ['Generalist'], Check Size $: $250k-$500k, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['No'], Geography: NYC, Additional notes for founders:: Overview is a venture capital firm investing in climate change solutions.
# added record
# record: Contact Name: Jinghan Hao, Investor (VC or Angel): Charge Ventures, Industry: ['AI/ML', 'B2B', 'B2C', 'Consumer', 'Digital Health', 'E-commerce', 'Enterprise Software', 'FemTech', 'Edtech', 'Wellness', 'SaaS', 'Mental Health', 'MedTech & Healthcare', 'Marketplace', 'Generalist'], Check Size $: $250k-$750k, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Brad Gillespie, Investor (VC or Angel): IA Ventures, Industry: ['AI/ML', 'B2B', 'Blockchain & Crypto', 'Cybersecurity', 'Deep tech', 'Fintech', 'SaaS', 'InsurTech', 'Enterprise Software', 'Generalist', 'Other', 'Digital Health', 'Marketplace', 'No code'], Check Size $: $1-$3m, Funding Stage: ['Pre-seed'], Do you lead rounds?: ['Yes', 'but equally happy to co-invest alongside qualified leads', 'Will also explore participatory if necessary'], # of cold outreach investments made:: 4, Additional notes for founders:: a bit more about me: http://j.mp/InvestmentPhilosophy
# added record
# record: Contact Name: Kailash Sundaram, Investor (VC or Angel): Detroit Venture Partners, Industry: ['B2B', 'E-commerce', 'DTC', 'Consumer', 'Fintech', 'Future of Work & Productivity', 'Gaming', 'SaaS'], Check Size $: $100K - $5M, Funding Stage: ['Pre-seed', 'Seed', 'Series A', 'Series B'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 3, Additional notes for founders:: We're the venture capital arm of Dan Gilbert, founder of Rocket Companies and owner of the Cleveland Cavaliers. Our investments include StockX, Finicity, Vroom, 100 Thieves, and Genius.
# added record
# record: Contact Name: Reena Jailwala, Investor (VC or Angel): Laconia, Industry: ['Adtech', 'AI/ML', 'B2B', 'Blockchain & Crypto', 'Digital Health', 'E-commerce', 'Fintech', 'Edtech', 'Enterprise Software', 'Future of Work & Productivity', 'Foodtech', 'Legal Tech', 'InsurTech', 'Legaltech', 'Martech', 'Marketplace', 'MedTech & Healthcare', 'Real Estate & Hospitality', 'SaaS', 'Retail Tech', 'Supply Chain'], Check Size $: $300K - $1M, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes', 'We lead rounds where we feel we are the best partner at the table and can add the most value to the company', 'Flexible between lead'], # of cold outreach investments made:: 1, Geography: US or Canada, Additional notes for founders:: We typically lead or co-lead seed rounds of $1M-$5M in b2b software companies revolutionizing legacy industries. Feel free to email me directly, submit a pitch through our website (http://bit.ly/laconiapitch) or sign up for an office hours meeting (http://bit.ly/laconiamentors). Can't wait to meet you!
# added record
# record: Contact Name: Kim Patel, Investor (VC or Angel): Lerer Hippeau / Individual, Industry: ['Adtech', 'AI/ML', 'B2B', 'B2C', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Hard Tech & Manufacturing', 'InsurTech', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS', 'Transport'], Check Size $: $1K - $4M, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed', 'Series A'], # of cold outreach investments made:: 5, Additional notes for founders:: Share information about your company and how much you want to raise - that is helpful!
# added record
# record: Contact Name: Alaina Hartley, Investor (VC or Angel): Greycroft, Industry: ['Wellness', 'B2C', 'Beauty', 'Beauty & wellness', 'CleanTech', 'Consumer', 'E-commerce', 'Fintech', 'Future of Work & Productivity', 'Marketplace', 'Real Estate & Hospitality', 'Supply Chain', 'Retail Tech', 'SaaS'], Check Size $: $500K-$50MM, Funding Stage: ['Seed', 'Series A', 'Series B', 'Series C', 'Taking it to IPO! 🎉'], Do you lead rounds?: ['Yes'], Additional notes for founders:: I respond to every email - but please give me ~5 business days to respond. Thank you!
# added record
# record: Contact Name: Cecilia Manduca, Investor (VC or Angel): Talis Capital, Industry: ['Adtech', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'CleanTech', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'InsurTech', 'SaaS'], Check Size $: $1M - $10m, Funding Stage: ['Series A', 'Series B']
# added record
# record: Contact Name: Shivam Parikh, Investor (VC or Angel): Individual, Industry: ['Adtech', 'AI/ML', 'All deep tech!', 'Aerospace', 'We work with people without college degrees! Let me know if you have one or not :)', 'B2B', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'Digital Health', 'Digital health', 'Wellness', 'BioTech', 'Deep tech', 'AR/VR', 'Agritech', 'Fintech', 'Industry Agnostic', 'Love crazy ideas', 'Retail Tech'], Check Size $: $0-$50k, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 0, Additional notes for founders:: Open to all ideas. Mainly focused in technology.
# added record
# record: Contact Name: Ana-Maria Yanakieva, Investor (VC or Angel): Outlier Ventures, Industry: ['AI/ML', 'B2B', 'B2C', 'Blockchain & Crypto', 'Enterprise Software', 'Fintech', 'Gaming', 'InsurTech', 'Marketplace', 'SaaS'], Check Size $: £50,000, Funding Stage: ['Idea/first check', 'Pre-seed'], # of cold outreach investments made:: 10, Additional notes for founders:: ana@ana.vc
#
# Vertical agnostic so long there is a decentralised tech component. Pre-seed/first check investment via an accelerator program.
# added record
# record: Contact Name: Jerry Chen, Investor (VC or Angel): Mucker Capital, Industry: ['Adtech', 'AI/ML', 'B2B', 'B2C', 'Digital Health', 'E-commerce', 'Fintech', 'SaaS', 'Mental Health', 'InsurTech', 'Foodtech', 'Marketplace'], Check Size $: 100k ~ some MM, Funding Stage: ['Pre-seed', 'Series A', 'Seed'], Do you lead rounds?: ['Both']
# added record
# record: Contact Name: Atin Batra, Investor (VC or Angel): Twenty Seven Ventures, Industry: ['AI/ML', 'B2B', 'Edtech', 'Future of Work & Productivity', 'SaaS'], Check Size $: $50K - $200K, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 1
# added record
# record: Contact Name: Charlie O'Donnell, Investor (VC or Angel): Brooklyn Bridge Ventures, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'Beauty', 'Wellness', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Growthtech', 'Hard Tech & Manufacturing', 'InsurTech', 'Legaltech', 'Marketplace', 'Media', 'Mental Health', 'No Code focus', 'Real Estate & Hospitality', 'Renewable Energy', 'Sustainable Materials', 'SaaS', 'Social Impact', 'Transport', 'Other'], Check Size $: $250,000 - $400,000, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 20, Geography: NYC area only
# added record
# record: Contact Name: Kunal Sethi, Investor (VC or Angel): Prithvi Ventures, Industry: ['CleanTech'], Check Size $: 500k, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Alexander Zemlyak, Investor (VC or Angel): LETA Capital, Industry: ['Adtech', 'AI/ML', 'All deep tech!', 'AR/VR', 'B2B', 'B2C', 'Consumer', 'Cybersecurity', 'Deep tech', 'Digital Health', 'Digital health', 'E-commerce', 'Edtech', 'Enterprise Software', 'Fintech', 'Foodtech', 'FemTech', 'Future of Work & Productivity', 'Generalist', 'Growthtech', 'Industry Agnostic', 'InsurTech', 'Legal Tech', 'Love crazy ideas', 'Marketplace', 'Martech', 'Media', 'No code', 'Transport', 'Supply Chain', 'SaaS', 'Retail Tech', 'Other'], Check Size $: $500k up to $5M, Funding Stage: ['Seed', 'Series A', 'Series B', 'Series C'], Do you lead rounds?: ['Yes', 'co-lead', 'Both'], # of cold outreach investments made:: 5, Additional notes for founders:: Focus on Russian-speaking global IT founders
# added record
# record: Contact Name: Alex Macdonald, Investor (VC or Angel): Alchemy, Industry: ['B2B', 'B2C', 'DTC', 'Enterprise Software', 'Marketplace'], Check Size $: $10k-500k, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: 3, Geography: UK, Additional notes for founders:: Please include deck 🙏🏽
# added record
# record: Contact Name: Peter Christman, Investor (VC or Angel): Chicago Ventures, Industry: ['Generalist', 'AI/ML', 'Aerospace', 'B2B', 'CleanTech', 'Consumer', 'Digital Health', 'Enterprise Software', 'Marketplace', 'Materials', 'Supply Chain'], Check Size $: $500K-$2.5M, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes', 'but equally happy to co-invest alongside qualified leads', 'Will also explore participatory if necessary'], # of cold outreach investments made:: 40%
# added record
# record: Contact Name: Doug Benowitz, Investor (VC or Angel): Colle Capital, Industry: ['Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Future of Work & Productivity', 'Hard Tech & Manufacturing', 'InsurTech', 'Marketplace', 'Mental Health', 'Real Estate & Hospitality', 'SaaS', 'Transport'], Check Size $: $500K+, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 2
# added record
# record: Contact Name: Masha Levin, Investor (VC or Angel): One Way Ventures, Industry: ['Aerospace', 'AR/VR', 'All deep tech!', 'Consumer', 'Cybersecurity', 'Edtech', 'Enterprise Software', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Generalist'], Check Size $: 500k-2mln, Funding Stage: ['Seed'], Do you lead rounds?: ['Yes'], Geography: United States, Additional notes for founders:: We invest in exceptional immigrant founders building their businesses in the United States or Canada,
# added record
# record: Contact Name: Helena Cavell, Investor (VC or Angel): Frontline Ventures, Industry: ['Adtech', 'Aerospace', 'AI/ML', 'B2B', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Future of Work & Productivity', 'InsurTech', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS'], Check Size $: $100K - $1M, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed']
# added record
# record: Contact Name: Shiva Kintali, Investor (VC or Angel): Individual, Industry: ['Industry Agnostic', 'AI/ML', 'B2B', 'B2C', 'BioTech', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'Edtech', 'Love crazy ideas', 'Marketplace', 'Mental Health', 'Renewable Energy', 'SaaS', 'Social Impact', 'Sustainable Materials', 'Wellness'], Check Size $: 25K - 100K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 3
# added record
# record: Contact Name: Oliver Dean, Investor (VC or Angel): Individual Angel, Industry: ['AI/ML', 'MedTech & Healthcare', 'Fintech', 'B2B', 'BioTech', 'B2C', 'Digital Health'], Check Size $: $10-50K, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['No', 'Most likely not but we do in select cases'], # of cold outreach investments made:: 3
# added record
# record: Contact Name: Olivia Hipkins, Investor (VC or Angel): Gaia Global Funds, Industry: ['Agritech', 'Blockchain & Crypto', 'CleanTech', 'FemTech', 'BioTech', 'Renewable Energy', 'Sustainable Materials', 'Transport', 'Supply Chain'], Check Size $: 300,000 - 3,000,000, Funding Stage: ['Seed', 'Series A', 'Series B'], Do you lead rounds?: ['Yes', 'No', 'but equally happy to co-invest alongside qualified leads'], # of cold outreach investments made:: 2, Geography: North America focus for now, plan to expand for Fund II, Additional notes for founders:: All investments are ESG-oriented - looking for innovative thinking to solve big challenges (climate change, increased regulation/transparency, decentralized finance, etc.).  I also consult for companies seeking to go to private markets, even if they don't fit our mandate.
# added record
# record: Contact Name: Tanner Potter, Investor (VC or Angel): Kickstart Fund, Industry: ['Consumer', 'Edtech', 'SaaS', 'Marketplace', 'Generalist'], Check Size $: $300k - $3M, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], Geography: Intermountain West (e.g., Utah, Colorado, Arizona, New Mexico), Additional notes for founders:: Target investments by geo, focusing on the Intermountain West (e.g., Utah, Colorado, Arizona, New Mexico).
# added record
# record: Contact Name: Abhinaya Konduru, Investor (VC or Angel): VC Fund, Industry: ['B2B', 'B2C', 'AI/ML', 'AR/VR', 'Consumer', 'Cybersecurity', 'Digital Health', 'E-commerce', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Gaming', 'Generalist', 'InsurTech', 'Marketplace', 'Mental Health', 'SaaS', 'Transport'], Check Size $: $250k - $500k, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['We lead rounds where we feel we are the best partner at the table and can add the most value to the company', 'or follow depending on the stage of the company', 'but equally happy to co-invest alongside qualified leads', 'Will also explore participatory if necessary'], Geography: US Midwest, Additional notes for founders:: No bio, pharma, vice (alcohol, gambling, cannabis)
# added record
# record: Contact Name: Jillian Cohn, Investor (VC or Angel): Mouro Capital, Industry: ['B2B', 'B2C', 'Blockchain & Crypto', 'Fintech', 'InsurTech', 'Marketplace', 'Real Estate & Hospitality', 'SaaS', 'Supply Chain'], Check Size $: $1-$15m, Funding Stage: ['Seed', 'Series A', 'Series B', 'Series C'], Do you lead rounds?: ['Yes', 'co-lead', 'Both'], # of cold outreach investments made:: 5, Geography: US, Latam, Canada
# added record
# record: Contact Name: Chris Corcoran, Investor (VC or Angel): Individual / 200ok.VC, Industry: ['AI/ML', 'B2B', 'Enterprise Software', 'No code', 'No Code focus', 'Fintech', 'Future of Work & Productivity', 'Love crazy ideas'], Check Size $: 10000, Funding Stage: ['Seed', 'Series A', 'Pre-seed', 'Idea/first check'], Do you lead rounds?: ['No'], Geography: SF / NYC / Paris, Additional notes for founders:: I’ve spent 10 years building developer products at Twilio and now at Algolia. I love APIs, developer experience and what’s possible when you give a builder the right tool. You can find me on Twitter at @chriscorcoran
# added record
# record: Contact Name: Danielle Strachman, Investor (VC or Angel): 1517 Fund, Industry: ['Aerospace', 'Agritech', 'AI/ML', 'B2B', 'BioTech', 'MedTech & Healthcare', 'Cybersecurity', 'Edtech', 'Enterprise Software', 'FemTech', 'Foodtech', 'Future of Work & Productivity', 'Hard Tech & Manufacturing', 'Marketplace', 'SaaS', 'We work with people without college degrees! Let me know if you have one or not :)'], Check Size $: $250K usually. $50K on occasion. , Funding Stage: ['Idea/first check', 'Pre-seed'], # of cold outreach investments made:: 10, Additional notes for founders:: Hi! Let me know if you are without a degree. We work mostly with drop outs!
# added record
# record: Contact Name: Mohammed Amdani, Investor (VC or Angel): Adapt Ventures, Industry: ['B2B', 'B2C', 'E-commerce', 'DTC', 'Consumer', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS'], Check Size $: $25,000K - $250,000K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Neil Kapur, Investor (VC or Angel): TTV Capital, Industry: ['Fintech', 'InsurTech'], Check Size $: $1-10M+, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Cheryl Campos, Investor (VC or Angel): Scout and Investment Partner at the Community Fund, Industry: ['FemTech', 'Beauty & wellness', 'Digital Health', 'Digital health', 'DTC', 'MedTech & Healthcare', 'Mental Health', 'Wellness'], Check Size $: $25-$50k, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Molly Rowe, Investor (VC or Angel): GSV Ventures , Industry: ['Edtech', 'Future of Work & Productivity'], Check Size $: $250K - $15M, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Batul Joffrey, Investor (VC or Angel): Kapor Capital, Industry: ['Digital Health', 'Social impact', 'MedTech & Healthcare', 'Generalist', 'Fintech', 'Enterprise Software', 'Edtech'], Check Size $: 250K-500K, Funding Stage: ['Seed', 'Pre-seed', 'Series A'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Alex Halliday, Investor (VC or Angel): Individual, Industry: ['B2B', 'E-commerce', 'DTC', 'Consumer', 'Enterprise Software', 'Future of Work & Productivity', 'SaaS', 'No code', 'growth tech'], Check Size $: $25K - $500K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed', 'Series A'], # of cold outreach investments made:: 0
# added record
# record: Contact Name: Colleen Wong, Investor (VC or Angel): GVC Partners, Industry: ['Social impact'], Check Size $: $50K - $150K, Funding Stage: ['Pre-seed', 'Seed'], # of cold outreach investments made:: 0, Additional notes for founders:: Please include your deck when reaching out.
# added record
# record: Contact Name: T bridge venture partners, Investor (VC or Angel): VC fund, Industry: ['B2B', 'Blockchain & Crypto', 'CleanTech', 'Renewable Energy', 'Real Estate & Hospitality', 'Industry Agnostic'], Check Size $: £50k-£3mil, Funding Stage: ['Idea/first check', 'Seed', 'Pre-seed', 'Series A', 'Series B'], Do you lead rounds?: ['Will also explore participatory if necessary'], Geography: Global
# added record
# record: Contact Name: Ashok Kamal, Investor (VC or Angel): Tech Coast Angels, Industry: ['Social impact', 'AI/ML', 'Adtech', 'All deep tech!', 'B2B', 'B2C', 'BioTech', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'Edtech', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Foodtech', 'Martech', 'Materials', 'MedTech & Healthcare', 'Mental Health', 'SaaS'], Check Size $: $100,000 - $500,000, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 3, Geography: US (SoCal), Additional notes for founders:: Focus on SoCal but open to everywhere in the US. Thanks!
# added record
# record: Contact Name: Jessica Li, Investor (VC or Angel): VC fund, Industry: ['B2B', 'Enterprise Software'], Check Size $: $100K - $300K, Funding Stage: ['Seed'], Additional notes for founders:: we invested post revenue, and I especially focus on healthcare payments, data infrastructure, and logistics analytics
# added record
# record: Contact Name: Michael Iasinskyi, Investor (VC or Angel): Solid5, Industry: ['Adtech', 'All deep tech!', 'AI/ML', 'B2B', 'AR/VR', 'Cybersecurity', 'Deep tech', 'E-commerce', 'Edtech', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Gaming', 'Generalist', 'growth tech', 'Growthtech', 'InsurTech', 'Legaltech', 'Marketplace', 'Martech', 'Media', 'No code', 'Real Estate & Hospitality', 'Retail Tech', 'SaaS', 'Transport'], Check Size $: $100-500k, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Most likely not but we do in select cases'], Geography: Western Europe, North America, Central/Eastern Europe, Israel, Latin America
# added record
# record: Contact Name: Hara Wang, Investor (VC or Angel): Third Derivative, Industry: ['CleanTech', 'Hard Tech & Manufacturing', 'Renewable Energy', 'Sustainable Materials', 'Social Impact', 'Transport'], Check Size $: $100K, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 30, Additional notes for founders:: We are an accelerator program that also provides access to global corporations, leading climate tech VCs, and a 250-people nonprofit think tank that focuses on accelerating market-based solutions for the clean energy economy.
# added record
# record: Contact Name: Sumeet Shah, Investor (VC or Angel): Swiftarc Ventures, Industry: ['B2C', 'Beauty', 'Beauty & wellness', 'Consumer', 'Digital Health', 'Digital health', 'DTC', 'E-commerce', 'FemTech', 'Social Impact'], Check Size $: $50k - $500k, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Flexible between lead', 'Will also explore participatory if necessary']
# added record
# record: Contact Name: Chris Moreno, Investor (VC or Angel): 80/20 Fund & Real Estate Tech Fund, Industry: ['B2B', 'B2C', 'CleanTech', 'Cybersecurity', 'Consumer', 'DTC', 'E-commerce', 'Enterprise Software', 'Edtech', 'Fintech', 'Future of Work & Productivity', 'growth tech', 'Legal Tech', 'Marketplace', 'We work with people without college degrees! Let me know if you have one or not :)', 'Transport', 'Supply Chain', 'SaaS', 'Retail Tech', 'Real Estate & Hospitality', 'MedTech & Healthcare', 'Hard Tech & Manufacturing'], Check Size $: Up to $250k , Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 17
# added record
# record: Contact Name: Nikita Singareddy, Investor (VC or Angel): RRE Ventures, Industry: ['B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'Digital Health', 'E-commerce', 'DTC', 'Consumer', 'Enterprise Software', 'Fintech', 'InsurTech', 'SaaS'], Check Size $: $250K - $8M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 4
# added record
# record: Contact Name: Themasap Khan, Investor (VC or Angel): Civilization Ventures, Industry: ['Agritech', 'BioTech', 'Digital Health', 'MedTech & Healthcare'], Check Size $: $100k - $Millions, Funding Stage: ['Idea/first check', 'Seed', 'Series A'], Do you lead rounds?: ['Yes'], Geography: SF based, but invest globally!, Additional notes for founders:: Civilization Ventures supports founders in building new platforms in areas such as cell and gene therapy, IO, gene editing, genomics/diagnostics, synthetic biology and digital health. We work closely with our portfolio companies on strategy, recruiting, operations, partnerships, fundraising and more.
# added record
# record: Contact Name: Mood Fund, Investor (VC or Angel): Angel Syndicate , Industry: ['Edtech'], Check Size $: 50000-500000 USD, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Both'], Geography: Europe
# added record
# record: Contact Name: David Boulton - Newzone, Investor (VC or Angel): VC Fund, Industry: ['Industry Agnostic'], Check Size $: $5-50m, Funding Stage: ['Series A', 'Series B'], Do you lead rounds?: ['Yes'], Geography: Europe, Additional notes for founders:: Feel free to reach out - david.boulton@newzone.vc
# added record
# record: Contact Name: Robert Moore, Investor (VC or Angel): Moore Fund, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Hard Tech & Manufacturing', 'InsurTech', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS', 'Transport'], Check Size $: $5 - $150K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], # of cold outreach investments made:: 0, Geography: Africa focused
# added record
# record: Contact Name: Rachel Horowitz, Investor (VC or Angel): individual, Industry: ['Aerospace', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'FemTech', 'Foodtech', 'Future of Work & Productivity', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS', 'Transport'], Check Size $: ~$10K , Funding Stage: ['Idea/first check', 'Pre-seed'], # of cold outreach investments made:: 0, Additional notes for founders:: I have 7 years of BD + Partnerships experience in the consumer space at brands like Plated, M. Gemi and Zola.  I love connecting with early stage startups where I can leverage my experience to help with GTM and distribution strategy.
# added record
# record: Contact Name: Diana Kontsevaia, Investor (VC or Angel): Dell Technologies Capital, Industry: ['AI/ML', 'B2B', 'All deep tech!', 'Cybersecurity', 'Deep tech', 'Enterprise Software', 'Future of Work & Productivity', 'No code', 'SaaS'], Check Size $: 5-10M, Funding Stage: ['Series A', 'Series B'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: Not sure, Additional notes for founders:: We are the financially-driven venture arm of Dell Technologies. We invest in enterprise needle-movers who will grow fast and where we can add value with our networks and operational experience. Though operating like a fund, we have the distinct advantage of leveraging Dell for opportunities where and when it makes sense (like joint GTM, OEM, etc). Our interests are enterprise infrastructure, from hardware to data to dev tools.
# added record
# record: Contact Name: Nicole Velho, Investor (VC or Angel): Individual, Industry: ['AI/ML', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'InsurTech', 'Marketplace', 'Media', 'SaaS'], Check Size $: £10K - £20K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], # of cold outreach investments made:: 1, Additional notes for founders:: Please feel free to email me for a 30 minute chat.
# added record
# record: Contact Name: Jacobo Cucalon, Investor (VC or Angel): Inkef Capital, Industry: ['AI/ML', 'All deep tech!', 'B2B', 'E-commerce', 'Digital Health', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'MedTech & Healthcare'], Check Size $: 1-15M, Funding Stage: ['Seed', 'Series A', 'Series B'], Do you lead rounds?: ['Yes', 'Will also explore participatory if necessary'], Geography: Europe
# added record
# record: Contact Name: JJ Kasper, Investor (VC or Angel): Blue Collective, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'Beauty', 'Wellness', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Growthtech', 'Hard Tech & Manufacturing', 'InsurTech', 'Legaltech', 'Marketplace', 'Media', 'Mental Health', 'No Code focus', 'Real Estate & Hospitality', 'Renewable Energy', 'Sustainable Materials', 'SaaS', 'Social Impact', 'Transport'], Check Size $: $250,000 - $2,000,000, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 10, Additional notes for founders:: Our strategy is and has always been to invest in 'off-the-radar' entrepreneurs. Many of our most successful investments have been from cold outreach and in founders that were passed over by many others before finding us. We always respond to cold emails. While we obviously only invest in a small percentage of founders we meet with, we aspire to be as accessible and helpful to any and all entrepreneurs, regardless of who they are or where they come from.
# added record
# record: Contact Name: Alexander Gornyi, Investor (VC or Angel): United Investors, Industry: ['Generalist'], Check Size $: $30K-$1M, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Both'], # of cold outreach investments made:: 30+, Additional notes for founders:: We are a syndicate
# added record
# record: Contact Name: Keyan Kazemian, Investor (VC or Angel): California Crescent Fund, Industry: ['Industry Agnostic', 'We work with people without college degrees! Let me know if you have one or not :)', 'Love crazy ideas'], Check Size $: 40K , Funding Stage: ['Idea/first check', 'Pre-seed'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: David Yakobovitch, Investor (VC or Angel): DataPower Ventures, Industry: ['AI/ML', 'All deep tech!', 'B2B', 'Cybersecurity', 'Deep tech', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Hard Tech & Manufacturing', 'No code'], Check Size $: 100k-250k, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: 5, Geography: Global, Additional notes for founders:: Please reach out at david@datapower.vc
# added record
# record: Contact Name: Joanna Maryewska, Investor (VC or Angel): SAP.iO Fund, Industry: ['B2B', 'Enterprise Software', 'SaaS'], Check Size $: $0-250K, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['No'], Additional notes for founders:: invests in breakthrough, pathfinding early-stage (Seed to Series A) enterprise software start-ups who are first to capitalize on emerging trends with potential to unlock significant value for SAP and its customers
# added record
# record: Contact Name: Grace Chen, Investor (VC or Angel): Individual Angel, Industry: ['B2C', 'Real Estate & Hospitality', 'AI/ML', 'B2B'], Check Size $: $3-10k, Funding Stage: ['Pre-seed', 'Idea/first check', 'Series A'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Kenny Tucker, Investor (VC or Angel): Angel Investor, Industry: ['AI/ML', 'All deep tech!', 'B2B', 'Blockchain & Crypto', 'Cybersecurity', 'Deep tech', 'Enterprise Software', 'etc.', 'Fintech', 'Future of Work & Productivity', 'Generalist', 'Industry Agnostic', 'SaaS', 'No code'], Check Size $: 25000-100000, Funding Stage: ['Idea/first check', 'Pre-seed'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 5, Geography: Developed world, mainly US, Additional notes for founders:: Operator turned Angel Investor, love to talk to founders early
# added record
# record: Contact Name: Bryan Lyandvert, Investor (VC or Angel): MetaProp Ventures, Industry: ['Real Estate & Hospitality', 'CleanTech'], Check Size $: $500K-$3M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes', 'No']
# added record
# record: Contact Name: Oren Kozlowski, Investor (VC or Angel): Founders Factory , Industry: ['Beauty', 'Wellness', 'Digital Health', 'E-commerce', 'DTC', 'Consumer', 'FemTech', 'Mental Health'], Check Size $: $100K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Sab, Investor (VC or Angel): Individual Angel, Industry: ['All deep tech!', 'BioTech', 'Cybersecurity', 'Deep tech', 'Digital Health', 'Fintech', 'MedTech & Healthcare', 'Mental Health', 'SaaS', 'Sustainable Material', 'Agritech', 'Aerospace', 'AR/VR', 'AI/ML', 'CleanTech'], Check Size $: 10000 - 150000, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: Two, Geography: US, India
# added record
# record: Contact Name: Faye Maidment, Investor (VC or Angel): Unshackled Ventures, Industry: ['Adtech', 'Aerospace', 'Agritech', 'AI/ML', 'B2B', 'B2C', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Hard Tech & Manufacturing', 'InsurTech', 'Marketplace', 'Media', 'Real Estate & Hospitality', 'SaaS', 'Transport', 'Industry Agnostic'], Check Size $: $250K - $300K, Funding Stage: ['Idea/first check', 'Pre-seed'], Additional notes for founders:: Looking forward to meeting you!
# added record
# record: Contact Name: Jennifer Phan, Investor (VC or Angel): BTOV, Industry: ['AI/ML', 'B2B', 'B2C', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Foodtech', 'Future of Work & Productivity', 'Marketplace', 'SaaS'], Check Size $: EUR 500K - 2M, Funding Stage: ['Pre-seed', 'Seed', 'Series A']
# added record
# record: Contact Name: Zerj Chung, Investor (VC or Angel): Insurtech Gateway, Industry: ['InsurTech'], Check Size $: $70k - $750k, Funding Stage: ['Seed', 'Pre-seed', 'Idea/first check'], Do you lead rounds?: ['Yes'], Geography: Global
# added record
# record: Contact Name: Richard Deulofeut, Investor (VC or Angel): Trust Ventures, Industry: ['Aerospace', 'Agritech', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Digital Health', 'Edtech', 'Fintech', 'Foodtech', 'Hard Tech & Manufacturing', 'InsurTech', 'Legaltech', 'Marketplace', 'Real Estate & Hospitality', 'Renewable Energy', 'Sustainable Materials', 'Social Impact'], Check Size $: $250,000 - $4,000,000, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 3, Additional notes for founders:: We are looking for companies who need regulatory and policy help, which we provide as our strategic value.
# added record
# record: Contact Name: Ana Maury Aguilar, Investor (VC or Angel): AC Ventures, Industry: ['AI/ML', 'B2B', 'B2C', 'CleanTech', 'E-commerce', 'DTC', 'Consumer', 'Fintech', 'SaaS'], Check Size $: $0.5M - 2.5M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['No'], # of cold outreach investments made:: 8, Additional notes for founders:: We are a global CVC based in Mexico City sponsored by Arca Continental. Second biggest Coca Cola Company bottler in Latam.
# https://www.linkedin.com/company/acv-vc/
# https://medium.com/@ACV_VC
#
# added record
# record: Contact Name: Laura Sillman, Investor (VC or Angel): Left lane , Industry: ['B2C', 'Beauty & wellness', 'Blockchain & Crypto', 'AI/ML', 'Consumer', 'Digital Health', 'Digital health', 'Edtech', 'FemTech', 'Fintech', 'E-commerce', 'Gaming', 'Future of Work & Productivity', 'InsurTech', 'Marketplace', 'Mental Health'], Check Size $: $5-60M, Funding Stage: ['Series A', 'Series B', 'Series C'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: Several!, Geography: USA, Europe, Israel , Additional notes for founders:: High growth consumer internet / SMEs. Industry agnostic - but no enterprise :)
# added record
# record: Contact Name: Alice Deng, Investor (VC or Angel): Bessemer Venture Partners, Industry: ['AI/ML', 'B2B', 'B2C', 'E-commerce', 'DTC', 'Consumer', 'Edtech', 'Enterprise Software', 'FemTech', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Marketplace', 'Media', 'SaaS'], Check Size $: $200K - $20M, Funding Stage: ['Seed', 'Series A', 'Series B']
# added record
# record: Contact Name: Sammy Abdullah, Investor (VC or Angel): Blossom Street Ventures, Industry: ['B2B', 'B2C', 'E-commerce', 'DTC', 'Consumer', 'Enterprise Software', 'Future of Work & Productivity', 'Growthtech', 'Legaltech', 'Marketplace', 'Mental Health', 'SaaS', 'Social Impact'], Check Size $: $500k to $1.5mm, Funding Stage: ['Series A', 'Series B', 'Series C'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 22, Additional notes for founders:: Reach out to me cold any time.  My email is on our website at blossomstreetventures.com
# added record
# record: Contact Name: Roman Shportko, Investor (VC or Angel): Charged Ventures, Industry: ['Blockchain & Crypto', 'AI/ML', 'All deep tech!', 'Love crazy ideas', 'Gaming'], Check Size $: 10-100K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['Flexible between lead', 'Accelerator'], # of cold outreach investments made:: 20, Geography: Global
# added record
# record: Contact Name: Blue Acre Capital, Investor (VC or Angel): Blue Acre, Industry: ['AI/ML', 'All deep tech!', 'B2C', 'B2B', 'Beauty', 'Blockchain & Crypto', 'Cybersecurity', 'E-commerce', 'Enterprise Software', 'FemTech', 'Mental Health', 'growth tech'], Check Size $: $10,000-$100,000, Funding Stage: ['Idea/first check', 'Seed', 'Pre-seed', 'Series A', 'Series B', 'Series C'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: <10, Geography: Global, Additional notes for founders:: We have the resources to help you co-build
# added record
# record: Contact Name: Jalen Gildersleeve, Investor (VC or Angel): Wiase Capital, Industry: ['AI/ML', 'BioTech', 'MedTech & Healthcare', 'CleanTech', 'Edtech', 'Enterprise Software', 'SaaS'], Check Size $: $50,000 - $1,000,000, Funding Stage: ['Pre-seed', 'Seed'], # of cold outreach investments made:: 2, Additional notes for founders:: Getting customers or be an industry professional with a lot of experience & network
# added record
# record: Contact Name: Leah Fessler, Investor (VC or Angel): NextView Ventures, Industry: ['Adtech', 'Agritech', 'Wellness', 'AI/ML', 'B2B', 'B2C', 'Beauty', 'Beauty & wellness', 'CleanTech', 'Consumer', 'DTC', 'Digital Health', 'E-commerce', 'Edtech', 'Legal Tech', 'Marketplace', 'Future of Work & Productivity', 'Generalist', 'Media', 'Industry Agnostic'], Check Size $: up to $2M, no lower bound, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes', 'Both'], Additional notes for founders:: Can’t wait to hear from you!
# added record
# ...
# added record
# record: Contact Name: Graham Carney, Investor (VC or Angel): GGV Capital, Industry: ['B2B', 'Enterprise Software', 'Future of Work & Productivity', 'Legal Tech', 'No Code focus', 'SaaS'], Check Size $: $500K to $100M, Funding Stage: ['Pre-seed', 'Seed', 'Series A', 'Series B', 'Series C', 'Taking it to IPO! 🎉'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Ryan Henry, Investor (VC or Angel): VC (family office), Industry: ['AI/ML', 'B2B', 'Cybersecurity', 'E-commerce', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Generalist', 'Martech', 'No code', 'SaaS'], Check Size $: $250k-$1m, Funding Stage: ['Seed', 'Pre-seed', 'Series A'], Do you lead rounds?: ['We lead rounds where we feel we are the best partner at the table and can add the most value to the company', 'but equally happy to co-invest alongside qualified leads', 'or follow depending on the stage of the company'], # of cold outreach investments made:: 2, Geography: North America
# added record
# record: Contact Name: Jane Lippencott, Investor (VC or Angel): Distributed, Industry: ['Blockchain & Crypto'], Check Size $: $250k-$10m, Funding Stage: ['Pre-seed', 'Seed', 'Series A', 'Idea/first check'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 5, Additional notes for founders:: Update Mar 2021 I moved from Winklevoss Capital to Distributed. Happy to speak with any founder building in the crypto/blockchain space.
# added record
# record: Contact Name: Chris Dixon, Investor (VC or Angel): Andreessen Horowitz, Industry: ['AI/ML', 'B2C', 'Consumer', 'Gaming', 'Social Impact', 'Love crazy ideas'], Check Size $: $50k-$2m, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['No'], Geography: USA, Canada, UK
# added record
# record: Contact Name: David Bromberg, Investor (VC or Angel): Open Water Accelerator, Industry: ['B2B', 'B2C', 'Fintech', 'Marketplace', 'SaaS'], Check Size $: Accelerator , Funding Stage: ['Idea/first check', 'Pre-seed'], Do you lead rounds?: ['No', 'Accelerator'], # of cold outreach investments made:: 10, Additional notes for founders:: Would love to help review your Open Water Accelerator applications before you apply. Send me an email anytime.
# added record
# record: Contact Name: Oli Strong, Investor (VC or Angel): Supernode Global, Industry: ['AR/VR', 'Adtech', 'AI/ML', 'B2B', 'B2C', 'Gaming', 'Media', 'SaaS'], Check Size $: 300k-1m, Funding Stage: ['Seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Kendall Gee-Wing, Investor (VC or Angel): Plucky Ventures, Industry: ['Adtech', 'All deep tech!', 'AI/ML', 'Agritech', 'B2B', 'CleanTech', 'Cybersecurity', 'Digital Health', 'E-commerce', 'Enterprise Software', 'Foodtech', 'Love crazy ideas', 'Generalist'], Check Size $: 50,000 and above, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Do you lead rounds?: ['No', 'I help founders find leads.']
# added record
# record: Contact Name: Elizabeth Yin, Investor (VC or Angel): Hustle Fund, Industry: ['AI/ML', 'B2B', 'Digital Health', 'Digital health', 'Fintech', 'SaaS'], Check Size $: $25k, Funding Stage: ['Pre-seed'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 15%, Additional notes for founders:: I will ask you to apply at Hustlefund.vc
# added record
# record: Contact Name: Becca Shmukler, Investor (VC or Angel): Laerdal Million Lives Fund, Industry: ['BioTech', 'MedTech & Healthcare', 'FemTech', 'Digital health'], Check Size $: $1M - $5M, Funding Stage: ['Seed', 'Series A', 'Series B'], Additional notes for founders:: The Laerdal Million Lives Fund is a new $100M fund that invests in digital health, medical device, and tech-enabled healthcare services companies that have direct life-saving impact. We are location-agnostic and are particularly interested in the following areas: maternal/neonatal health, frontline/emergency care, and medical education/training.
# added record
# record: Contact Name: Gil X. Hernandez, Investor (VC or Angel): Earnest Capital, Industry: ['AI/ML', 'E-commerce', 'DTC', 'Consumer', 'Fintech', 'Future of Work & Productivity', 'B2B', 'SaaS'], Check Size $: $100K - $200K, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Additional notes for founders:: No hardware
# added record
# record: Contact Name: Ollie Richards, Investor (VC or Angel): MMC Ventures, Industry: ['AI/ML', 'All deep tech!', 'Cybersecurity', 'Blockchain & Crypto', 'Deep tech', 'Digital Health', 'Enterprise Software', 'Fintech', 'SaaS'], Check Size $: £250k-£5m (Seed), up to £10m (Series A), Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes', 'co-lead'], Geography: Europe + UK
# added record
# record: Contact Name: Eric Ramos, Investor (VC or Angel): Florida Funders, Industry: ['Adtech', 'AI/ML', 'AR/VR', 'B2B', 'Cybersecurity', 'Digital health', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Gaming', 'Generalist', 'InsurTech', 'Legal Tech', 'Love crazy ideas', 'Marketplace', 'Martech', 'No code', 'SaaS', 'Retail Tech', 'We work with people without college degrees! Let me know if you have one or not :)'], Check Size $: $250K - $1M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['We lead rounds where we feel we are the best partner at the table and can add the most value to the company', 'Yes', 'or follow depending on the stage of the company'], # of cold outreach investments made:: 3, Additional notes for founders:: Even if you’re not raising right now, I’d love to meet or speak with founders.
# added record
# record: Contact Name: Stephen Chou, Investor (VC or Angel): Translink Capital, Industry: ['AR/VR', 'B2C', 'Consumer', 'Gaming', 'Wellness'], Check Size $: $1M-$6M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes', 'co-lead', 'or follow depending on the stage of the company']
# added record
# record: Contact Name: CATS.VC, Investor (VC or Angel): CATS.VC, Industry: ['B2B', 'B2C', 'Cybersecurity', 'Enterprise Software', 'Foodtech', 'Fintech', 'Supply Chain', 'SaaS', 'Marketplace', 'Digital Health', 'Digital health', 'Gaming', 'Industry Agnostic', 'Future of Work & Productivity', 'E-commerce', 'Edtech'], Check Size $: €200K – €1M, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Most likely not but we do in select cases'], # of cold outreach investments made:: 3, Geography: geo-agnostic
# added record
# record: Contact Name: Avra Durack , Investor (VC or Angel): National Grid Partners, Industry: ['AI/ML', 'B2B', 'CleanTech', 'Cybersecurity', 'Enterprise Software', 'Renewable Energy', 'Sustainable Materials', 'SaaS'], Check Size $: $1M - $10M, Funding Stage: ['Pre-seed', 'Seed', 'Series A'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Avi Rao, Investor (VC or Angel): Emerson Collective, Industry: ['Aerospace', 'All deep tech!', 'AI/ML', 'CleanTech', 'Foodtech', 'Hard Tech & Manufacturing', 'Supply Chain', 'Materials', 'Renewable Energy', 'Sustainable Materials', 'Transport'], Check Size $: $5 - $25M, Funding Stage: ['Series B', 'Series C', 'Series A', 'Taking it to IPO! 🎉'], Do you lead rounds?: ['Most likely not but we do in select cases'], Geography: San Francisco
# added record
# record: Contact Name: Hussein Kanji, Investor (VC or Angel): Hoxton Ventures, Industry: ['All deep tech!', 'Digital health', 'Enterprise Software', 'Love crazy ideas', 'SaaS'], Check Size $: $500k - $5m, Funding Stage: ['Seed', 'Pre-seed'], Do you lead rounds?: ['Yes']
# added record
# record: Contact Name: Serg Mol, Investor (VC or Angel): UBC, Industry: ['Fintech'], Check Size $: 100, Funding Stage: ['Pre-seed'], Do you lead rounds?: ['No']
# added record
# record: Contact Name: Tony Olivito, Investor (VC or Angel): Comeback Capital, Industry: ['Adtech', 'Agritech', 'AI/ML', 'B2B', 'Cybersecurity', 'Digital Health', 'Enterprise Software', 'Fintech', 'Future of Work & Productivity', 'Generalist', 'InsurTech', 'Industry Agnostic', 'Legaltech', 'SaaS', 'Supply Chain'], Check Size $: $100k - $250k, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Yes'], Geography: Midwest, Mountains, Southwest, South, Mid-Atlantic, etc.  Anywhere in the US except Silicon Valley and New York, Additional notes for founders:: We typically respond within 48 hours. This is the best way to contact: https://www.comeback.vc/entrepreneurs
# added record
# record: Contact Name: Maya Kass, Investor (VC or Angel): PEMBROKE., Industry: ['Beauty', 'Wellness', 'CleanTech', 'Digital Health', 'Mental Health', 'SaaS'], Check Size $: $10K - $250K, Funding Stage: ['Seed', 'Series A'], Do you lead rounds?: ['Yes'], # of cold outreach investments made:: 2
# added record
# record: Contact Name: Teddy Blank, Investor (VC or Angel): First Star Ventures, Industry: ['Aerospace', 'Agritech', 'AI/ML', 'B2B', 'BioTech', 'MedTech & Healthcare', 'Blockchain & Crypto', 'CleanTech', 'Cybersecurity', 'Enterprise Software', 'Fintech', 'Foodtech', 'Future of Work & Productivity', 'Gaming', 'Hard Tech & Manufacturing', 'InsurTech', 'Real Estate & Hospitality', 'SaaS', 'Transport', 'All deep tech!'], Check Size $: $200K - $1M, Funding Stage: ['Idea/first check', 'Pre-seed', 'Seed'], Additional notes for founders:: We invest in founders using data and new ways of computing to make the world better/faster/smarter/healthier/safer. We focus on companies that have a novel technological innovation and/or proprietary data/access at the core of the company.
# added record
# record: Contact Name: Toby Allen, Investor (VC or Angel): InvestMill, Industry: ['AI/ML', 'AR/VR', 'Deep tech', 'Enterprise Software', 'Gaming', 'Future of Work & Productivity', 'No code'], Check Size $: 20000, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Will also explore participatory if necessary'], # of cold outreach investments made:: 50, Geography: Europe
# added record
# record: Contact Name: Randall Zuccalmaglio, Investor (VC or Angel): Nasdaq Ventures , Industry: ['AI/ML', 'Blockchain & Crypto', 'Fintech', 'Marketplace', 'No code', 'Real Estate & Hospitality', 'SaaS', 'B2B'], Check Size $: $1-10M, Funding Stage: ['Seed', 'Series A', 'Series B'], Do you lead rounds?: ['We lead rounds where we feel we are the best partner at the table and can add the most value to the company']
# added record
# record: Contact Name: Sam Patel, Investor (VC or Angel): Individual Angel, Industry: ['All deep tech!', 'AR/VR', 'CleanTech', 'Social Impact'], Check Size $: 100000, Funding Stage: ['Pre-seed', 'Seed'], Do you lead rounds?: ['Will also explore participatory if necessary'], # of cold outreach investments made:: 1, Geography: India, USA, Europe
# added record
# record:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 # load_angel_investor_records(angel_records)
# ----> 2 load_no_warm_intro_investor_records(no_warm_intro_records)
#
# Cell In[10], line 199, in load_no_warm_intro_investor_records(records)
#     196 metadatas.append(metadata)
#     197 ids.append(record_id)
# --> 199 collection.add(documents=[formatted_record], metadatas=[metadata], ids=[record_id])
#     200 print("added record")
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/chromadb/api/models/Collection.py:154, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#     151 if embeddings is None:
#     152     # At this point, we know that one of documents or images are provided from the validation above
#     153     if documents is not None:
# --> 154         embeddings = self._embed(input=documents)
#     155     elif images is not None:
#     156         embeddings = self._embed(input=images)
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/chromadb/api/models/Collection.py:633, in Collection._embed(self, input)
#     628 if self._embedding_function is None:
#     629     raise ValueError(
#     630         "You must provide an embedding function to compute embeddings."
#     631         "https://docs.trychroma.com/embeddings"
#     632     )
# --> 633 return self._embedding_function(input=input)
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/chromadb/api/types.py:193, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     192 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 193     result = call(self, input)
#     194     return validate_embeddings(maybe_cast_one_to_many_embedding(result))
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/chromadb/utils/embedding_functions.py:201, in OpenAIEmbeddingFunction.__call__(self, input)
#     199 # Call the OpenAI Embedding API
#     200 if self._v1:
# --> 201     embeddings = self._client.create(
#     202         input=input, model=self._deployment_id or self._model_name
#     203     ).data
#     205     # Sort resulting embeddings by index
#     206     sorted_embeddings = sorted(embeddings, key=lambda e: e.index)
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/openai/_base_client.py:1261, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247 def post(
#    1248     self,
#    1249     path: str,
#    (...)
#    1256     stream_cls: type[_StreamT] | None = None,
#    1257 ) -> ResponseT | _StreamT:
#    1258     opts = FinalRequestOptions.construct(
#    1259         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1260     )
# -> 1261     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1048     stream_cls=stream_cls,
#    1049 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
