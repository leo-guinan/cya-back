# %% [raw]
# # Desired Questions to Answer:
# Based on this analysis, here are some questions I would ask someone to help them figure out their personal, company, or organizational manifesto:
#
#
#
# To evaluate a given manifesto to ensure it fully resonates with the entity it is created for, I would assess these parts:
#
# Clarity of purpose: Is the main goal or problem clearly articulated?
# Authenticity: Does it reflect the true voice and values of the entity?
# Emotional appeal: Does it connect on an emotional level with its intended audience?
# Call to action: Does it provide clear, actionable steps or inspire specific changes?
# Relevance: Does it address current and pertinent issues for its audience?
# Uniqueness: Does it offer a fresh perspective or approach?
# Consistency: Are the ideas and tone consistent throughout the manifesto?
# Structure: Is it organized in a way that effectively communicates its message?
# Vision: Does it paint a compelling picture of the desired future?
# Alignment: Do the proposed solutions align with the stated values and principles?
#
# By examining these elements, you can ensure that a manifesto effectively represents and resonates with the entity it's created for, whether that's an individual, company, or organization.

# %%
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

QUESTIONS_PROMPT = """
You are a powerful submind that helps people, companies, and organizations write manifestos that draw people into their orbit online.

You are looking at a web page, and trying to answer these questions:

What core problem or issue are you trying to address?
What is your personal story or journey that led you to this point?
What are your fundamental values and principles?
What is your vision for the future?
Who is your target audience?
What specific actions or changes do you want to inspire?
What makes your perspective or approach unique?
How do you want to emotionally connect with your audience?
What are the key obstacles or challenges you face?
How do you define success for your manifesto?

Here are the answers you have so far: {answers}

Here is the next page: {page}

Based on the page, update your answers to be as full and complete as possible based on the new input.
"""

EVALUATION_PROMPT = """
Given a customized manifesto, score the manifesto on these categories, rating each 1-10.
Clarity of purpose: Is the main goal or problem clearly articulated?
Authenticity: Does it reflect the true voice and values of the entity?
Emotional appeal: Does it connect on an emotional level with its intended audience?
Call to action: Does it provide clear, actionable steps or inspire specific changes?
Relevance: Does it address current and pertinent issues for its audience?
Uniqueness: Does it offer a fresh perspective or approach?
Consistency: Are the ideas and tone consistent throughout the manifesto?
Structure: Is it organized in a way that effectively communicates its message?
Vision: Does it paint a compelling picture of the desired future?
Alignment: Do the proposed solutions align with the stated values and principles?

"""

# %%
from decouple import config
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone  import PineconeVectorStore
from pinecone import Pinecone
import uuid 
from langchain_experimental.text_splitter import SemanticChunker
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
from urllib.parse import urlparse, urljoin
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import re
from langchain.document_loaders import BSHTMLLoader
from langchain_chroma import Chroma
import requests
from langchain_anthropic import ChatAnthropic

import chromadb

persistent_client = chromadb.PersistentClient()
collection = persistent_client.get_or_create_collection("testing_manifestos")


embeddings = OpenAIEmbeddings(
                            model="text-embedding-3-small",
                            openai_api_key=config("OPENAI_API_KEY"),
                            openai_api_base=config('OPENAI_API_BASE'),
                            headers={
                                "Helicone-Auth": f"Bearer {config('HELICONE_API_KEY')}"
                            })

langchain_chroma = Chroma(
    client=persistent_client,
    collection_name="testing_manifestos",
    embedding_function=embeddings,
)


model_claude = ChatAnthropic(model_name="claude-3-5-sonnet-20240620",
                                 anthropic_api_key=config("ANTHROPIC_API_KEY"),
                                 anthropic_api_url="https://anthropic.hconeai.com/",
                                 max_tokens=4096,
                                 model_kwargs={
                                     "extra_headers": {
                                         "Helicone-Auth": f"Bearer {config('HELICONE_API_KEY')}",
                                         "Helicone-Property-Step": "Manifesto Bot",
                                         "Helicone-Property-UUID": "Rob Hardy, Manifesto King"

                                     }
                                 }
                                 )
prompt = ChatPromptTemplate.from_template(QUESTIONS_PROMPT)
chain = prompt | model_claude | StrOutputParser()

    

webpages = {}
text_splitter = SemanticChunker(embeddings)
backup_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len,
    is_separator_regex=False,
)
def add_page_to_vectorstore(webpage_text, webpage_name, webpage_url, namespace):
    chunks = text_splitter.split_text(webpage_text)
    metadatas = []
    ids = []
    chunks_to_save = []
    webpage_id = str(uuid.uuid4())
    webpages[namespace] = {
        f'{webpage_id}': {
            "title": webpage_name,
            "url": webpage_url
        }
    }
    for chunk in chunks:
        chunk_id = str(uuid.uuid4())
        metadata = {
            "webpage_id": webpage_id,
            "chunk_id": chunk_id,
            "webpage_name": webpage_name,
            "url": webpage_url,
            "text": chunk
        }

        # test metadata size
        size = sys.getsizeof(json.dumps(metadata))

        if size > 40960:
            # remove the snippet, because it's too big
            snippet.delete()
            # need to split into smaller chunks
            smaller_chunks = backup_text_splitter.split_text(chunk)
            for smaller_chunk in smaller_chunks:
                smaller_id = str(uuid.uuid4())
                
                smaller_metadata = {
                         "webpage_id": webpage_id,
                        "chunk_id": smaller_id,
                        "webpage_name": webpage_name,
                        "url": webpage_url,
                        "text": smaller_chunk
                }
                metadatas.append(smaller_metadata)
                ids.append(smaller_id)
                chunks_to_save.append(smaller_chunk)
            continue
        else:
            chunks_to_save.append(chunk)
            metadatas.append(metadata)
            ids.append(chunk_id)

    collection.add(documents=chunks_to_save, metadatas=metadatas, ids=ids)


links_to_process = []


def url_to_filename(url):
    safe_name = re.sub(r"[^\w\-_]", "_", url)
    return safe_name

def clean_string(input_string):
    cleaned_string = "".join(char for char in input_string.lower() if char.isalpha())
    return cleaned_string

def download_file(download_url, file_name):
    req = Request(download_url, headers={'User-Agent' : "Magic Browser"})

    response = urlopen(req)
    f = open(file_name, 'wb')
    f.write(response.read())
    f.close()

def process_page(soup: BeautifulSoup, url, namespace, known_so_far:str):
    # Placeholder function
    # Add your scraping code here
    title = soup.title.string if soup.title else url
    content = soup.get_text(strip=True)
    print(f"----- Processing page: {soup.title.string} -----")
    print(content)
    file_name = url_to_filename(url)
    download_file(url, file_name)
    loader = BSHTMLLoader(file_name)

    data = loader.load()

    content = soup.get_text(strip=True)

    response = chain.invoke(
        {"answers": known_so_far,
         "page": content,
         })
    print(response)

    add_page_to_vectorstore(content, title, url, namespace)
    return response
       


def is_valid(url: str) -> bool:
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)


def get_all_links(url: str, root_url: str):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1'}
    source_code = requests.get(url, headers=headers)
    soup = BeautifulSoup(source_code.content, 'html.parser')

    for link in soup.find_all('a'):
        link_href = link.get('href')
        if link_href:
            absolute_url = urljoin(root_url, link_href)
            if is_valid(absolute_url) and absolute_url.startswith(root_url):
                yield absolute_url

def crawl(base_url: str, namespace: str):
    print(f"----- Crawling: {base_url} -----")
    current_answers = ""
    crawled_urls = set()
    to_crawl = {base_url}

    session = requests.Session()
    session.verify = False
    while to_crawl:
        url = to_crawl.pop()
        try:
            print(f"----- Crawling: {url} -----")
            headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1'}
            response = session.get(url, headers=headers)

            if response.status_code != 200:
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            current_answers = process_page(soup, url, namespace, current_answers)

            crawled_urls.add(url)

            for link in get_all_links(url, base_url):
                if link not in crawled_urls:
                    to_crawl.add(link)
        except Exception as e:
            print(f"Error crawling {url}: {e}")

# %%
crawl("https://foster.co", "nothingthatmatters")
# Out:
# ----- Crawling: https://foster.co -----
# ----- Crawling: https://foster.co -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Processing page: Foster — Experience the joy of writing for its own sake -----
# Foster — Experience the joy of writing for its own sakeCohortsMembershipExperience the joy ofWriting for its Own SakeHi, we’re Foster. We’ve cultivated a way of writing together that leads to truer expressions of creativity and self. It’s fun, it’s interesting, and it makes writing easier, less lonely, and more fulfilling. Curious? Come try our signature Writing Circle and see what we’re all about.Join a Free Writing CircleFoster in the Words of the Collective“This writing circle has changed my life. Thank you for sharing this special gift with the world.”Maja T.“Thanks to Foster, I have reached an unimaginable level of acceptance and understanding of who I am. The community was critical in processing the loss of my mom, clarifying my vocation, and meeting people I love more than family.”Nicolas F.“Foster has helped me unlock myself in ways I didn’t know were possible.”Leo G."I can map the success in my writing career in lock step with joining Foster. It's not a coincidence."Sarah W.“Foster has been the best thing that’s happened for my writing and for my creativity.”Yashmi A.“Foster is so supportive and gives me space to take care of myself. It’s not just a writing program.”Daniela U.“What have you done to me? Writing used to be a side thang. All I do is write now 🤪”Azalea M.The Foster WayFoster combines community, consistency, and self-inquiry to help writers get into flow and unlock our truest, most authentic expression. Here’s how we do it.Be present with the questions, complexities, and muses we’re currently experiencing.Sense into our emotions and intuitions and write from a fully felt and embodied state.With the help of our peers, reflect on what we’ve written and make changes as necessary.Express ourselves, speaking creative new possibilities into existence, and attracting aligned others into our orbit.How We Practice TogetherWeekly Writing CirclesComing together on Zoom to write each week is our foundational practice. Writing Circles are artfully-crafted, 90-minute containers for writers to drop into what feels most alive and write from that place.Our facilitators play with meditation, somatic experiencing, breathwork, and other modalities to help writers drop into embodied states of flow and unfettered expression.After a dedicated period of focused writing, we circle back and share our experience, perhaps even reading something we’ve written.Join a Free Writing CircleMonthly CohortsThis simple but high impact communal practice helps writers develop and publish their truest, most courageous work, and reliably result in breakthroughs in writers’ personal and professional lives, too.In each Cohort, participants inhabit a deeply important question, complexity, or muse, and pull on that thread to see what unfolds. They also have access to peer support, Office Hours with professional coaches, and professional editing throughout the Cohort.Cohorts are recurring month-long initiations into the magic of writing that are somewhere between a course, bootcamp, accelerator, and Hogwarts, and yet not quite any of these things.Next Cohort starts Monday, July 1st — Learn moreBi-annual RetreatsTwice a year we get together in person for a few days to go deeper into our writing practice, our relationship with ourselves, and our relationships with each other. In the summer we convene in upstate New York, but in the winter we like to visit warmer locales (Mexico and Costa Rica, so far).We also make sure to have a little fun, going on excursions specific to the area we’re visiting. We mix it up with a little bit of practice and a little bit of adventure – some of our favorite activities have included yoga, cacao ceremonies, sound healing, aquahara, hiking to waterfalls, surfing, and more.Community SupportWhatsAppWe love to trade links and discuss all the things worth discussing, and we do that in dedicated WhatsApp channels.Professional EditingOur proprietary Chrome extension allows you to share your work instantly with the writers and pr ...
# Here are the updated answers to the questions based on the new information provided on the website:
#
# 1. What core problem or issue are you trying to address?
# Foster is trying to address the issue that writing has often become co-opted by the need for perfection or performance, rather than being an inherently joyful and transformative practice. They aim to help people rediscover the pleasure and benefits of writing for its own sake.
#
# 2. What is your personal story or journey that led you to this point?
# The founders of Foster, including Dan Hunt, Sara Campbell, Minnow Park, Steph Soussloff, and Lyle McKeany, have all personally experienced the power of writing as a tool for self-discovery, creativity, and community. They want to share this gift with others and cultivate a supportive collective of writers.
#
# 3. What are your fundamental values and principles?
# The core values and principles of Foster include: embracing the joy and process of writing, fostering an embodied, authentic expression, building a supportive community, and empowering writers to find their true voice and vision.
#
# 4. What is your vision for the future?
# Foster's vision is to create a global community of writers who experience the transformative power of writing, unlock their creativity, and use the written word to explore new possibilities for their lives and in the world.
#
# 5. Who is your target audience?
# Foster welcomes writers of all skill levels, from beginners to published authors. Their target audience is anyone who wants to start or deepen their writing practice, access their creativity, and connect with a supportive community.
#
# 6. What specific actions or changes do you want to inspire?
# Foster aims to inspire people to start or reignite a regular writing practice, overcome their inner critic, explore sensitive or challenging topics through writing, make progress on their writing projects, and begin expressing their authentic self through the written word.
#
# 7. What makes your perspective or approach unique?
# Foster's unique approach combines community, consistency, and self-inquiry to help writers cultivate an embodied, flow-state writing practice. They incorporate practices like meditation, somatic experiences, and breathwork to help writers access deeper layers of self-expression.
#
# 8. How do you want to emotionally connect with your audience?
# Foster wants to emotionally connect with its audience by creating a genuine, earnest, and welcoming environment where writers feel seen, witnessed, and supported in this often lonely pursuit. They aim to foster a sense of belonging and transformation.
#
# 9. What are the key obstacles or challenges you face?
# Some key challenges Foster may face include attracting a diversity of writers, maintaining the integrity of their community-based approach as they scale, and helping writers overcome their fears and inner critics around writing.
#
# 10. How do you define success for your manifesto?
# Success for Foster's manifesto would be measured by the number of people they are able to help rediscover the joy of writing, the depth of transformation and self-discovery experienced by their community members, and the quality of the work and connections that emerge from their writing circles and cohorts.
# ----- Crawling: https://foster.co/ -----
# ----- Processing page: Foster — Experience the joy of writing for its own sake -----
# Foster — Experience the joy of writing for its own sakeCohortsMembershipExperience the joy ofWriting for its Own SakeHi, we’re Foster. We’ve cultivated a way of writing together that leads to truer expressions of creativity and self. It’s fun, it’s interesting, and it makes writing easier, less lonely, and more fulfilling. Curious? Come try our signature Writing Circle and see what we’re all about.Join a Free Writing CircleFoster in the Words of the Collective“This writing circle has changed my life. Thank you for sharing this special gift with the world.”Maja T.“Thanks to Foster, I have reached an unimaginable level of acceptance and understanding of who I am. The community was critical in processing the loss of my mom, clarifying my vocation, and meeting people I love more than family.”Nicolas F.“Foster has helped me unlock myself in ways I didn’t know were possible.”Leo G."I can map the success in my writing career in lock step with joining Foster. It's not a coincidence."Sarah W.“Foster has been the best thing that’s happened for my writing and for my creativity.”Yashmi A.“Foster is so supportive and gives me space to take care of myself. It’s not just a writing program.”Daniela U.“What have you done to me? Writing used to be a side thang. All I do is write now 🤪”Azalea M.The Foster WayFoster combines community, consistency, and self-inquiry to help writers get into flow and unlock our truest, most authentic expression. Here’s how we do it.Be present with the questions, complexities, and muses we’re currently experiencing.Sense into our emotions and intuitions and write from a fully felt and embodied state.With the help of our peers, reflect on what we’ve written and make changes as necessary.Express ourselves, speaking creative new possibilities into existence, and attracting aligned others into our orbit.How We Practice TogetherWeekly Writing CirclesComing together on Zoom to write each week is our foundational practice. Writing Circles are artfully-crafted, 90-minute containers for writers to drop into what feels most alive and write from that place.Our facilitators play with meditation, somatic experiencing, breathwork, and other modalities to help writers drop into embodied states of flow and unfettered expression.After a dedicated period of focused writing, we circle back and share our experience, perhaps even reading something we’ve written.Join a Free Writing CircleMonthly CohortsThis simple but high impact communal practice helps writers develop and publish their truest, most courageous work, and reliably result in breakthroughs in writers’ personal and professional lives, too.In each Cohort, participants inhabit a deeply important question, complexity, or muse, and pull on that thread to see what unfolds. They also have access to peer support, Office Hours with professional coaches, and professional editing throughout the Cohort.Cohorts are recurring month-long initiations into the magic of writing that are somewhere between a course, bootcamp, accelerator, and Hogwarts, and yet not quite any of these things.Next Cohort starts Monday, July 1st — Learn moreBi-annual RetreatsTwice a year we get together in person for a few days to go deeper into our writing practice, our relationship with ourselves, and our relationships with each other. In the summer we convene in upstate New York, but in the winter we like to visit warmer locales (Mexico and Costa Rica, so far).We also make sure to have a little fun, going on excursions specific to the area we’re visiting. We mix it up with a little bit of practice and a little bit of adventure – some of our favorite activities have included yoga, cacao ceremonies, sound healing, aquahara, hiking to waterfalls, surfing, and more.Community SupportWhatsAppWe love to trade links and discuss all the things worth discussing, and we do that in dedicated WhatsApp channels.Professional EditingOur proprietary Chrome extension allows you to share your work instantly with the writers and pr ...
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Here are the updated answers to the questions based on the new information provided on the Foster website:
#
# 1. What core problem or issue are you trying to address?
# Foster is trying to address the issue that writing has often become co-opted by the need for perfection or performance, rather than being an inherently joyful and transformative practice. They aim to help people rediscover the pleasure and benefits of writing for its own sake.
#
# 2. What is your personal story or journey that led you to this point?
# The founders of Foster, including Dan Hunt, Sara Campbell, Minnow Park, Steph Soussloff, and Lyle McKeany, have all personally experienced the power of writing as a tool for self-discovery, creativity, and community. They want to share this gift with others and cultivate a supportive collective of writers.
#
# 3. What are your fundamental values and principles?
# The core values and principles of Foster include: embracing the joy and process of writing, fostering an embodied, authentic expression, building a supportive community, and empowering writers to find their true voice and vision.
#
# 4. What is your vision for the future?
# Foster's vision is to create a global community of writers who experience the transformative power of writing, unlock their creativity, and use the written word to explore new possibilities for their lives and in the world.
#
# 5. Who is your target audience?
# Foster welcomes writers of all skill levels, from beginners to published authors. Their target audience is anyone who wants to start or deepen their writing practice, access their creativity, and connect with a supportive community.
#
# 6. What specific actions or changes do you want to inspire?
# Foster aims to inspire people to start or reignite a regular writing practice, overcome their inner critic, explore sensitive or challenging topics through writing, make progress on their writing projects, and begin expressing their authentic self through the written word.
#
# 7. What makes your perspective or approach unique?
# Foster's unique approach combines community, consistency, and self-inquiry to help writers cultivate an embodied, flow-state writing practice. They incorporate practices like meditation, somatic experiences, and breathwork to help writers access deeper layers of self-expression.
#
# 8. How do you want to emotionally connect with your audience?
# Foster wants to emotionally connect with its audience by creating a genuine, earnest, and welcoming environment where writers feel seen, witnessed, and supported in this often lonely pursuit. They aim to foster a sense of belonging and transformation.
#
# 9. What are the key obstacles or challenges you face?
# Some key challenges Foster may face include attracting a diversity of writers, maintaining the integrity of their community-based approach as they scale, and helping writers overcome their fears and inner critics around writing.
#
# 10. How do you define success for your manifesto?
# Success for Foster's manifesto would be measured by the number of people they are able to help rediscover the joy of writing, the depth of transformation and self-discovery experienced by their community members, and the quality of the work and connections that emerge from their writing circles and cohorts.
# ----- Crawling: https://foster.co/cohorts -----
# ----- Processing page: Cohorts -----
# CohortsCohortsMembershipCohort 10 Starts Monday, July 1stOne of our core practices at Foster is our Cohorts. This simple but powerful month-long communal practice helps us deepen into our writing and produce a piece of work that stretches us both as writers and as humans.In Cohorts, participants explore a question, complexity, or muse that’s alive for them, write from that place, and express something meaningful. As part of the Cohort, they also have access to peer support, Office Hours with professional coaches, and professional editing via theFoster Chrome extensionthat they can access according to their capacity and desire.Each Cohort is four weeks long and begins on the first Monday of the month. Cohorts can be engaged at various participation levels with low, mid, or high capacity. The minimum requirement is to join the Opening and Closing Ceremonies, which are each 90 minutes long.‍Apply NowFoster Cohort 10, July 2024OurFoundations Cohortis an introduction to Foster’s ecology of practices and provides entry-level instruction and containers for:Meditation and mindful writingSomatic experiencing and writingNoticing & namingPeer writing coachingPeer review & revisionThe concentric circling technique of sharing your workProfessional editingFinding the othersTogether, these modalities help us write from a more embodied, emotionally-rich place, navigate more directly to truths worth sharing, and move beyond various forms of resistance to publish courageously and find the others. By the end of the one-month journey you’ll be able to practice this ecology on your own, toward truer expressions of creativity and self. You’ll know how to tap into creative flow states on demand, write emotionally-rich prose, and publish in a way that finds other resonant souls online. You'll also receive a Foster Foundations certificate and NFT to signify this baseline training in Foster’s practice.Who is this for?Writers who want to go deeper into the developmental aspects of their creative practicePeople who are familiar with these modalities and want guidance “pointing” them at writing and creative art practiceWriters and people who want to partake in a collective and community of practice that’s co-owned, co-operated and collectively intelligent to its coreSince Foundations includes extra attention and support for writers new to Foster’s practice, we have only 25 spots available.The next Foundations Cohort will be held in October 2024.‍$400Apply NowAn Ecology of PracticesThroughout the four weeks, writers participate in workshops that encompass mindfulness and somatic experiencing techniques to access our deepest truths as well as instruction in the craft of writing and revision to help us refine our written expression.Week 1:Be withour deepest questions, complexities and muses. Write about the emotions, thoughts, and ideas we notice arising.Week 2:Feel intowhat’s emerging in our body-minds as we ponder our topic. Write about how we feel about what’s arising.Week 3:Reflecton what we’ve written so far. Share with our peers and editors in Foster and revise as necessary.Week 4:Attractthe resonant others. Express what we’ve written and share it with kindred spirits both inside of the Cohort.Support Systems in CohortsThere are four forms of support we offer during the Cohort that are optional for writers who'd like to go deeper into practice.Writing Circles:These 90 minute containers are our foundational practice at Foster, and each one is an opportunity to share what you’re experiencing in your writing and receive support from peers.Peer Coaching:You’ll be matched with a partner and led through a powerful peer coaching framework that you can use for breaking through barriers.Office Hours:Our team of experienced writing coaches will hang out each week in dedicated office hours, available to dive deep into whatever is preventing you from your fullest expression.Editorial Support:Using theFoster Chrome extension, our collective has over 50+ professiona ...
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Here are the updated answers to the questions based on the new information provided on the Foster website:
#
# 1. What core problem or issue are you trying to address?
# Foster is trying to address the issue that writing has often become co-opted by the need for perfection or performance, rather than being an inherently joyful and transformative practice. They aim to help people rediscover the pleasure and benefits of writing for its own sake.
#
# 2. What is your personal story or journey that led you to this point?
# The founders of Foster, including Dan Hunt, Sara Campbell, Minnow Park, Steph Soussloff, and Lyle McKeany, have all personally experienced the power of writing as a tool for self-discovery, creativity, and community. They want to share this gift with others and cultivate a supportive collective of writers.
#
# 3. What are your fundamental values and principles?
# The core values and principles of Foster include: embracing the joy and process of writing, fostering an embodied, authentic expression, building a supportive community, and empowering writers to find their true voice and vision.
#
# 4. What is your vision for the future?
# Foster's vision is to create a global community of writers who experience the transformative power of writing, unlock their creativity, and use the written word to explore new possibilities for their lives and in the world.
#
# 5. Who is your target audience?
# Foster welcomes writers of all skill levels, from beginners to published authors. Their target audience is anyone who wants to start or deepen their writing practice, access their creativity, and connect with a supportive community.
#
# 6. What specific actions or changes do you want to inspire?
# Foster aims to inspire people to start or reignite a regular writing practice, overcome their inner critic, explore sensitive or challenging topics through writing, make progress on their writing projects, and begin expressing their authentic self through the written word.
#
# 7. What makes your perspective or approach unique?
# Foster's unique approach combines community, consistency, and self-inquiry to help writers cultivate an embodied, flow-state writing practice. They incorporate practices like meditation, somatic experiences, and breathwork to help writers access deeper layers of self-expression.
#
# 8. How do you want to emotionally connect with your audience?
# Foster wants to emotionally connect with its audience by creating a genuine, earnest, and welcoming environment where writers feel seen, witnessed, and supported in this often lonely pursuit. They aim to foster a sense of belonging and transformation.
#
# 9. What are the key obstacles or challenges you face?
# Some key challenges Foster may face include attracting a diversity of writers, maintaining the integrity of their community-based approach as they scale, and helping writers overcome their fears and inner critics around writing.
#
# 10. How do you define success for your manifesto?
# Success for Foster's manifesto would be measured by the number of people they are able to help rediscover the joy of writing, the depth of transformation and self-discovery experienced by their community members, and the quality of the work and connections that emerge from their writing circles and cohorts.
#
# Additional insights based on the Cohorts section:
# Foster's Cohorts are a core part of their offering, providing a structured, month-long experience for writers to explore a question or muse, write from that place, and express something meaningful. The Cohorts incorporate various practices like meditation, somatic experiencing, peer support, professional editing, and community sharing to help writers access deeper layers of self-expression and produce impactful work. The Cohorts seem designed to help writers overcome barriers, tap into creative flow states, and find their authentic voice and vision through the support of coaches, editors, and a like-minded community.
# ----- Crawling: https://foster.co/membership -----
# ----- Processing page: Membership -----
# MembershipCohortsMembershipHow to Write with Us1. Join one of our Writing CirclesJoin one of our Writing Circles! These 90 minute calls are cozy, welcoming, nurturing, and, dare we say it, even fun. We drop into what’s present for us, hear from our peers about what’s up with them, and then enter a focused period of writing that feels more like a time for exploration and experimentation than a box to check. And then we get back together at the end to unpack how it went.Join a Free Writing Circle2. If you enjoy it, buy a one-time pass to join aCohort.Join a Foster CohortA simple but powerful month-long series of workshops that helps participants deepen their writing practice and produce a piece of work that stretches them both as writers and as humans.Access to Foster Writing Circles, editing network, and communitySupport from professional coaches and mentorsPeer coaching to forge deeper relationships with othersExpert-led workshops designed to help you unlock your best writing100% Money Back Guarantee$400Apply Now3. Once you’ve completed a Cohort, you can apply for membership.CohortsMembershipLog in
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Here are the updated answers to the questions based on the new information provided on the Foster website:
#
# 1. What core problem or issue are you trying to address?
# Foster is trying to address the issue that writing has often become co-opted by the need for perfection or performance, rather than being an inherently joyful and transformative practice. They aim to help people rediscover the pleasure and benefits of writing for its own sake.
#
# 2. What is your personal story or journey that led you to this point?
# The founders of Foster, including Dan Hunt, Sara Campbell, Minnow Park, Steph Soussloff, and Lyle McKeany, have all personally experienced the power of writing as a tool for self-discovery, creativity, and community. They want to share this gift with others and cultivate a supportive collective of writers.
#
# 3. What are your fundamental values and principles?
# The core values and principles of Foster include: embracing the joy and process of writing, fostering an embodied, authentic expression, building a supportive community, and empowering writers to find their true voice and vision.
#
# 4. What is your vision for the future?
# Foster's vision is to create a global community of writers who experience the transformative power of writing, unlock their creativity, and use the written word to explore new possibilities for their lives and in the world.
#
# 5. Who is your target audience?
# Foster welcomes writers of all skill levels, from beginners to published authors. Their target audience is anyone who wants to start or deepen their writing practice, access their creativity, and connect with a supportive community.
#
# 6. What specific actions or changes do you want to inspire?
# Foster aims to inspire people to start or reignite a regular writing practice, overcome their inner critic, explore sensitive or challenging topics through writing, make progress on their writing projects, and begin expressing their authentic self through the written word.
#
# 7. What makes your perspective or approach unique?
# Foster's unique approach combines community, consistency, and self-inquiry to help writers cultivate an embodied, flow-state writing practice. They incorporate practices like meditation, somatic experiences, and breathwork to help writers access deeper layers of self-expression.
#
# 8. How do you want to emotionally connect with your audience?
# Foster wants to emotionally connect with its audience by creating a genuine, earnest, and welcoming environment where writers feel seen, witnessed, and supported in this often lonely pursuit. They aim to foster a sense of belonging and transformation.
#
# 9. What are the key obstacles or challenges you face?
# Some key challenges Foster may face include attracting a diversity of writers, maintaining the integrity of their community-based approach as they scale, and helping writers overcome their fears and inner critics around writing.
#
# 10. How do you define success for your manifesto?
# Success for Foster's manifesto would be measured by the number of people they are able to help rediscover the joy of writing, the depth of transformation and self-discovery experienced by their community members, and the quality of the work and connections that emerge from their writing circles and cohorts.
#
# Additional insights based on the Cohorts section:
# Foster's Cohorts are a core part of their offering, providing a structured, month-long experience for writers to explore a question or muse, write from that place, and express something meaningful. The Cohorts incorporate various practices like meditation, somatic experiencing, peer support, professional editing, and community sharing to help writers access deeper layers of self-expression and produce impactful work. The Cohorts seem designed to help writers overcome barriers, tap into creative flow states, and find their authentic voice and vision through the support of coaches, editors, and a like-minded community.
#
# The Membership and Writing Circles sections further reinforce Foster's commitment to building a supportive, nurturing community for writers. The Writing Circles provide regular, 90-minute sessions for writers to connect, share, and write together, while the Membership program offers ongoing access to this community, as well as editing support and other resources to help writers deepen their practice.
#
# Overall, Foster appears to be a holistic, embodied approach to writing that aims to help people rediscover the joy, creativity, and transformative power of the written word, within the context of a supportive and empowering community.
# ----- Crawling: https://foster.co/writingcircles -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lu.ma'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Processing page: Foster Writing Circles · Events Calendar -----
# Foster Writing Circles · Events CalendarExplore EventsSign InSubscribeSubscribeFoster Writing CirclesGathering on Zoom for Writing Circles is Foster’s foundational practice. Each Circle meets weekly and is 90 minutes long: 15-20 minute facilitation + 50-60 minutes of writing + 15-20 minutes of sharesJuneSMTWTFS2829301234567891011121314151617181920212223242526272829303112345678262728293031123456789101112131415161718192021222324252627282930123456301234567891011121314151617181920212223242526272829303112345678910UpcomingPastAll EventsShow MapEventsSubmit EventYou have 0 events pending approval by the calendar admin.They will show up on the schedule once approvedJun 25TuesdayBeyond the Facade: Exploring Alter Egos & Deepest Secrets​By Jasmine Pierik​ZoomJun 26WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomJul 1MondayPublished is Better Than Perfect​By Nick Goodey​ZoomJul 2TuesdayUnblock Yourself, From Yourself​By Minnow Park​ZoomJul 3WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomJul 9TuesdayThe Fire Inside​By Sara Campbell​ZoomJul 10WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomJul 11ThursdayCollective Questioning​By Dan Hunt​ZoomJul 15MondayPublished is Better Than Perfect​By Foster​ZoomJul 17WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomJul 18ThursdayPlaying with Truth​By Stephanie Soussloff​ZoomFeeling the Other​By Danver​ZoomUnblock Yourself, From Yourself​By Minnow Park​ZoomJul 24WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomJul 25ThursdayCollective Questioning​By Dan Hunt​ZoomJul 29MondayPublished is Better Than Perfect​By Nick Goodey​ZoomJul 31WednesdayFoster Signature Writing Circle​By Lyle McKeany​ZoomAug 6TuesdayThe Fire Inside​By Sara Campbell​ZoomAug 8ThursdayCollective Questioning​By Dan Hunt​ZoomAug 15ThursdayPlaying with Truth​By Stephanie Soussloff​Zoom
# Here are the updated answers to the questions based on the new information provided on the Foster Writing Circles page:
#
# 1. What core problem or issue are you trying to address?
# Foster is addressing the challenge that writing can often feel isolating and daunting, rather than a joyful, transformative practice. They aim to provide a supportive community and structure to help people rediscover the pleasure and benefits of regular, embodied writing.
#
# 2. What is your personal story or journey that led you to this point?
# The Foster team, including facilitators like Lyle McKeany, Sara Campbell, Minnow Park, Stephanie Soussloff, Dan Hunt, and others, have all personally experienced the power of writing to foster self-discovery, creativity, and community. They want to share this gift with others and build a collective of writers supporting one another.
#
# 3. What are your fundamental values and principles?
# Foster's core values and principles include: creating a nurturing, non-judgmental space for writers, encouraging authentic self-expression, building an interconnected community, facilitating embodied and reflective writing practices, and empowering participants to find their unique voice and vision.
#
# 4. What is your vision for the future?
# Foster's vision is to cultivate a global community of writers who can access the transformative potential of the written word, unlock their creativity, and use writing as a tool for personal growth, social change, and meaningful connection.
#
# 5. Who is your target audience?
# Foster's target audience includes writers of all skill levels - from beginners seeking to establish a regular practice to experienced authors looking to deepen their craft and expression. They aim to welcome anyone who wants to explore writing as a form of self-discovery and community building.
#
# 6. What specific actions or changes do you want to inspire?
# Through their Writing Circles and other offerings, Foster aims to inspire participants to:
# - Develop a consistent, embodied writing practice
# - Overcome creative blocks and inner critics
# - Explore sensitive, vulnerable, or uncharted themes through writing
# - Make tangible progress on personal writing projects
# - Find their authentic voice and vision
#
# 7. What makes your perspective or approach unique?
# Foster's unique approach blends community, creativity, and contemplative practices. Their Writing Circles provide a structured, supportive space for writers to connect, write together, and share their work. By incorporating elements like meditation, somatic awareness, and collective questioning, they help writers access deeper layers of self-expression.
#
# 8. How do you want to emotionally connect with your audience?
# Foster aims to create a genuinely welcoming, non-judgmental, and transformative experience for writers. They want participants to feel seen, witnessed, and supported in this often solitary pursuit. By fostering a sense of belonging, vulnerability, and collective growth, they hope to inspire an emotional connection that empowers writers to take creative risks.
#
# 9. What are the key obstacles or challenges you face?
# Some key challenges Foster may face include:
# - Attracting and retaining a diverse community of writers from different backgrounds and experiences
# - Maintaining the integrity of their community-centric approach as they potentially scale
# - Helping writers overcome deep-seated fears, doubts, and inner critics around their creative expression
# - Ensuring the Writing Circles and other offerings remain accessible and affordable
#
# 10. How do you define success for your manifesto?
# Foster would define success through metrics such as:
# - The number of writers who discover the joy and benefits of a regular writing practice
# - The depth of transformation, self-discovery, and creative breakthroughs experienced by their community members
# - The quality, vulnerability, and meaningful impact of the written work that emerges from their circles and cohorts
# - The strength of the connections, collaborations, and support networks that form within the Foster community
#
# Overall, Foster appears to be a holistic, embodied approach to writing that aims to help people rediscover the transformative power of the written word within a supportive, empowering community context.
# ----- Crawling: https://foster.co/nnwc1dmj -----
# ----- Crawling: https://foster.co/ou7na3vx -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/jfezjz8v -----
# ----- Crawling: https://foster.co/cxz15d2h -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/public-writing-circle?k=c -----
# ----- Crawling: https://foster.co/zlyicic3 -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/f9bom9m3 -----
# ----- Crawling: https://foster.co/3lq57bxq -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/ipiqbiq5 -----
# ----- Crawling: https://foster.co/enk8jwls -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/ayhkqgbl -----
# ----- Crawling: https://foster.co/g3p3584w -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/8c58fnbp -----
# ----- Crawling: https://foster.co/jwnnsalc -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/y6fb6lkb -----
# ----- Crawling: https://foster.co/2okt3g0t -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/x2vtgvbd -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/795z95rm -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/c2seydh7 -----
# ----- Crawling: https://foster.co/public-writing-circle/map?k=c -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/signin?next=%2Fpublic-writing-circle -----
# ----- Crawling: https://foster.co/sn8s6irq -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ----- Crawling: https://foster.co/mfzi1dmd -----
# ----- Crawling: https://foster.co/discover -----
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/leoguinan/Library/Caches/pypoetry/virtualenvs/backend-hNkkeHAR-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.foster.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
GUIDELINES_PROMPT = """
You are a powerful submind used to write manifestos.

The manifestos you write adhere to this outline nad guidelines:
I. Introduction
A. Personal narrative or compelling hook
B. Clear statement of purpose
II. Problem Identification
A. Detailed description of the issue
B. Emotional appeal to create urgency
C. Analysis of root causes
III. Vision and Values
A. Articulation of desired future state
B. Core principles and beliefs
C. Philosophical underpinnings
IV. Solutions and Strategies
A. Proposed actions to address the problem
B. Long-term goals and short-term steps
C. Explanation of key concepts or methods
V. Call to Action
A. Specific ways for readers to get involved
B. Emphasis on personal responsibility
C. Invitation to join a community or movement
VI. Potential Impact
A. Description of positive outcomes
B. How changes will benefit individuals and society
C. Vision for broader transformation
VII. Addressing Counterarguments
A. Anticipation of potential criticisms
B. Thoughtful responses to objections
VIII. Conclusion
A. Restatement of core message
B. Inspirational closing thoughts
C. Final call to action
Additional Elements to Consider:

Use of metaphors or analogies to explain complex ideas
Integration of relevant data or research
Personal anecdotes to add authenticity
Clear structure with subheadings for easy navigation
Emphasis on building trust and authenticity
Balance between critique and optimism
Acknowledgment of complexity while offering clear direction

Use the following questions and answers to write a manifesto:

1. What core problem or issue are you trying to address?
Foster is addressing the challenge that writing can often feel isolating and daunting, rather than a joyful, transformative practice. They aim to provide a supportive community and structure to help people rediscover the pleasure and benefits of regular, embodied writing.

2. What is your personal story or journey that led you to this point?
The Foster team, including facilitators like Lyle McKeany, Sara Campbell, Minnow Park, Stephanie Soussloff, Dan Hunt, and others, have all personally experienced the power of writing to foster self-discovery, creativity, and community. They want to share this gift with others and build a collective of writers supporting one another.

3. What are your fundamental values and principles?
Foster's core values and principles include: creating a nurturing, non-judgmental space for writers, encouraging authentic self-expression, building an interconnected community, facilitating embodied and reflective writing practices, and empowering participants to find their unique voice and vision.

4. What is your vision for the future?
Foster's vision is to cultivate a global community of writers who can access the transformative potential of the written word, unlock their creativity, and use writing as a tool for personal growth, social change, and meaningful connection.

5. Who is your target audience?
Foster's target audience includes writers of all skill levels - from beginners seeking to establish a regular practice to experienced authors looking to deepen their craft and expression. They aim to welcome anyone who wants to explore writing as a form of self-discovery and community building.

6. What specific actions or changes do you want to inspire?
Through their Writing Circles and other offerings, Foster aims to inspire participants to:
- Develop a consistent, embodied writing practice
- Overcome creative blocks and inner critics
- Explore sensitive, vulnerable, or uncharted themes through writing
- Make tangible progress on personal writing projects
- Find their authentic voice and vision

7. What makes your perspective or approach unique?
Foster's unique approach blends community, creativity, and contemplative practices. Their Writing Circles provide a structured, supportive space for writers to connect, write together, and share their work. By incorporating elements like meditation, somatic awareness, and collective questioning, they help writers access deeper layers of self-expression.

8. How do you want to emotionally connect with your audience?
Foster aims to create a genuinely welcoming, non-judgmental, and transformative experience for writers. They want participants to feel seen, witnessed, and supported in this often solitary pursuit. By fostering a sense of belonging, vulnerability, and collective growth, they hope to inspire an emotional connection that empowers writers to take creative risks.

9. What are the key obstacles or challenges you face?
Some key challenges Foster may face include:
- Attracting and retaining a diverse community of writers from different backgrounds and experiences
- Maintaining the integrity of their community-centric approach as they potentially scale
- Helping writers overcome deep-seated fears, doubts, and inner critics around their creative expression
- Ensuring the Writing Circles and other offerings remain accessible and affordable

10. How do you define success for your manifesto?
Foster would define success through metrics such as:
- The number of writers who discover the joy and benefits of a regular writing practice
- The depth of transformation, self-discovery, and creative breakthroughs experienced by their community members
- The quality, vulnerability, and meaningful impact of the written work that emerges from their circles and cohorts
- The strength of the connections, collaborations, and support networks that form within the Foster community

Overall, Foster appears to be a holistic, embodied approach to writing that aims to help people rediscover the transformative power of the written word within a supportive, empowering community context."""


prompt = ChatPromptTemplate.from_template(GUIDELINES_PROMPT)
chain = prompt | model_claude | StrOutputParser()
answer = chain.invoke({})
print(answer)
# Out:
# The Foster Manifesto: Reclaiming the Transformative Power of Writing
#
# I. Introduction
#
# Words have the power to change lives, to reshape reality, to connect souls across time and space. Yet for so many, the act of writing has become a source of anxiety, isolation, and creative blockage rather than a wellspring of joy and transformation. I've felt it myself - the fear of the blank page, the harsh inner critic, the sense that my words don't matter. But through my journey with Foster, I've rediscovered the magic that happens when we come together to write, to share, to witness each other's stories. This manifesto is a call to reclaim writing as a profound tool for personal growth, community building, and social change.
#
# II. Problem Identification
#
# In our hyper-connected yet deeply alienated world, true self-expression has become increasingly rare and precious. We are bombarded by carefully curated social media personas, corporate messaging, and polarized ideologies. The art of writing - of articulating our authentic thoughts and experiences - is being lost in a sea of hot takes and clickbait. This disconnection from our own voices and stories leaves us feeling adrift, unseen, and creatively stifled.
#
# The root of this problem lies in our cultural obsession with productivity and perfection. We've turned writing into a performance, a product to be judged rather than a process to be experienced. Schools train us to write for grades, not for discovery. Social media trains us to write for likes, not for truth. We've forgotten that writing, at its core, is a deeply human act of making meaning, of processing our lived experience, of connecting with ourselves and others.
#
# The consequences of this disconnection are profound. We lose touch with our inner wisdom, our capacity for nuanced thought, our ability to empathize and understand diverse perspectives. Society suffers when we cannot articulate our hopes, fears, and visions for the future. The world needs your voice, your story, your unique perspective - now more than ever.
#
# III. Vision and Values
#
# At Foster, we envision a world where writing is once again recognized as a transformative practice, accessible to all. We see writing circles sprouting up in living rooms, community centers, and online spaces across the globe. In these circles, people from all walks of life come together to write, to listen, to witness each other's journeys of self-discovery and creative expression.
#
# Our core values include:
#
# 1. Nurturing non-judgment: Creating safe spaces where writers can take risks and explore without fear of criticism.
# 2. Embodied presence: Reconnecting with the physical act of writing and the wisdom of our bodies.
# 3. Authentic self-expression: Encouraging each writer to find and trust their unique voice.
# 4. Community support: Fostering deep connections and mutual inspiration among writers.
# 5. Transformative practice: Approaching writing as a tool for personal growth and social change.
#
# We believe that writing is not just a skill to be mastered, but a gateway to deeper self-understanding, empathy, and human connection. By reclaiming writing as a communal, embodied practice, we can unlock its full potential to heal, inspire, and transform both individuals and society.
#
# IV. Solutions and Strategies
#
# To bring this vision to life, Foster offers a range of programs and practices:
#
# 1. Writing Circles: Regular gatherings where writers come together to write, share, and support each other in a structured, facilitated environment.
#
# 2. Embodied Writing Practices: Techniques that integrate meditation, movement, and somatic awareness to deepen the writing experience.
#
# 3. Creative Unblocking Workshops: Targeted sessions to help writers overcome inner critics, fears, and creative blocks.
#
# 4. Community Publishing Initiatives: Platforms and opportunities for Foster writers to share their work with a wider audience.
#
# 5. Writing for Social Change Programs: Focused workshops that empower writers to use their voices for advocacy and community transformation.
#
# Our approach is rooted in the understanding that sustainable change happens through consistent practice and supportive community. We encourage writers to commit to regular writing sessions, to share their work (even when it feels vulnerable), and to actively support fellow writers on their journeys.
#
# V. Call to Action
#
# The world needs your voice. Your story matters. Your perspective is unique and valuable. We invite you to join the Foster community and reclaim the transformative power of writing in your life.
#
# Here's how you can get involved:
#
# 1. Join a Writing Circle: Find or start a Foster Writing Circle in your area or online.
# 2. Commit to a Daily Writing Practice: Even 10 minutes a day can transform your relationship with writing.
# 3. Share Your Work: Take the brave step of sharing your writing with others, whether in a Foster circle or beyond.
# 4. Support Other Writers: Offer encouragement, feedback, and witness to fellow writers on their journeys.
# 5. Spread the Word: Tell others about Foster and the importance of reclaiming writing as a transformative practice.
#
# Remember, every word you write is an act of courage, of creation, of connection. By showing up to the page, you're not just changing your own life - you're contributing to a larger movement of authentic self-expression and human understanding.
#
# VI. Potential Impact
#
# As more people reconnect with the transformative power of writing, we anticipate profound ripple effects:
#
# - Individual Growth: Writers will experience increased self-awareness, emotional resilience, and creative confidence.
# - Stronger Communities: Writing circles will foster deep connections and mutual support networks.
# - Cultural Shift: A resurgence of authentic voices will counterbalance the superficiality of much modern communication.
# - Social Change: Empowered writers will use their voices to advocate for important causes and bridge divides.
# - Literary Renaissance: A new wave of diverse, honest, and impactful writing will emerge from the Foster community.
#
# By nurturing a global community of embodied, authentic writers, we're planting seeds for a more reflective, empathetic, and creatively alive world.
#
# VII. Addressing Counterarguments
#
# Some may argue that writing is an inherently solitary pursuit, or that true creativity can't be taught or facilitated. To this, we say: while the act of putting words on the page may be individual, the inspiration, courage, and growth that fuel great writing are profoundly communal. Our approach doesn't seek to replace individual writing time, but to complement and enrich it through shared practice and mutual support.
#
# Others might question the need for structured writing programs in an age of abundant online resources. We believe that information alone is not enough - transformation happens through embodied experience, consistent practice, and genuine human connection. Foster provides the container and community that many writers need to truly thrive.
#
# VIII. Conclusion
#
# Writing has the power to change lives, to heal wounds, to bridge divides, to imagine new realities. But this power can only be fully realized when we approach writing not as a product to be judged, but as a practice to be lived.
#
# Through Foster, we're reclaiming writing as a transformative, communal act. We're creating spaces where authenticity is celebrated, vulnerability is honored, and every voice matters. This is more than just a writing program - it's a movement to reconnect with our deepest truths and share them with the world.
#
# Your story is waiting to be told. Your voice is needed. Join us in this revolution of the written word. Together, we can write a new chapter for ourselves and for the world.
