# %% [markdown]
# Danielle Info:
# I love getting a solid cold email or DM from founders!
#
# No need for an intro to 1517.
#
# Some things will make your message standout and get a response (faster than others)🧵:
# 1:51 PM · Oct 7, 2022
# Related posts
#
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# I delete a lot of canned spam from founders. They go something like this:
#
# "Danielle/1517/Dear Sir/Ma'am [ick],
#
# My name is X. I'm doing Y and raising Z amount of money. Here's my calendar to set up a time to chat."
#
# This doesn't work to get investor attention. Here's what does:
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# Personalize your email! I want to understand:
#
# - Why you're writing to me and 1517 **specifically**
# - If you fit our dropout, student, or sci-fi tech thesis
# - If you're raising an angel or preseed (<$2M) round
#
# https://1517fund.com/post/thesis
#
# This is the bare minimum! Better yet if you:
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# Add something to humanize you and personalize the email further:
#
# - What makes you you?
# - When you're not working on your startup, what do you love doing?
# - What's your fav hobby from the past?
# - Have a pet? Include a picture!
#
# I'm a people person, mini details catch my eye!
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# Lastly, read up on our work to make sure we're a good fit for you!
#
# https://medium.com/1517/a-1517-anti-pitch-playbook-683f70ffa85c
#
# https://1517fund.com/post/moving-ahead
#
# https://1517fund.com/post/full-circle-playing-the-long-game
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# Send me a great email or DM if you check all the boxes above! My email isn't rocket science to guess.
#
# Or get in touch through our contact form. We answer 85 - 90% of submissions! Materials are 2D and you're 3D so we love to chat with lots of people!
# 1517fund.com
# 1517 Fund - Backing Dropouts, Students & SciFi Science
# 1517 Fund is an anti-establishment educational institution and VC firm backing founders at the earliest stages of their careers and companies.
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 7, 2022
# Lastly, you don't have to be a founder to message me. I love hearing from teens, students, makers and those early on their journey!
#
# I have an ice cream meeting later today to talk to a student about what to do with their college woes. Happy to help!
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Oct 8, 2022
# Some clarification:
#
# We are age agnostic. Portfolio includes 16 yr olds and 50+ yr olds. College dropout (or never went), student, or sci-fi tech founders are all great.
#
# We haven’t expanded much outside North America. Looking forward to being more global as we expand the team!
# Danielle Strachman 💗🐈
# @DStrachman
# ·
# Dec 11, 2023
# And if you do write to me, please add a calendar link -- anything to save some back and forth is immensely helpful on cutting down on email Tetris!

# %%
THESIS = """
We have a very specific thesis at 1517 Fund: we focus on backing founders without degrees. While we’re happy to work with and support those with degrees and those currently in school, we exist to support those who otherwise wouldn’t get a second look from traditional investors due to their credential status.

‍

This is intentional. When Michael and Danielle cofounded the Thiel Fellowship back in 2010, it was nearly impossible to land a meeting with Sand Hill Road firms without some kind of pedigree. It was even harder for younger founders. Even since then, despite big talk about backing founders without degrees, many firms still defer to scouts at top schools or some other similar credential.

‍

Fellows from those first few Thiel Fellowship classes built and continue to build world-changing companies (like Luminar) and many still struggled to land those important first few meetings with the traditional tracked institutions for capital. This is even though a disproportionate percentage of the largest venture-backed technology companies in history were founded by founders without impressive credentials or a laundry list of experience.

‍

That’s why 1517 Fund exists. While most capital fights for scraps among the same credentialing institutions and corporate tracks, we prioritize working with the founders who otherwise wouldn’t get a second look due to a checkbox on a worn-out diligence checklist.

‍

We sometimes say we also work with founders “outside of tracked institutions.” We’re looking to back those founders whose backstories are strange or aren’t going to be seen as impressive by credentialists at a cocktail party.

‍

That also means we’ll work with founders earlier than most firms and get as many leading indicators about their competence as possible. We have a community of 3,000+ people, all of whom we’ve met and vetted, for this reason. If we meet somebody when they’re a college freshman, it may be years until they’re actually raising money.

‍

But between our community, our grant program, and working with our existing portfolio companies, we’ll have better indicators of that person’s abilities than a line on a resume. We tell our LPs that we're pros in "talent identification" for this reason. You can learn more about a person through building a community and tracking them over time than you can about where they went to school.

‍

This doesn’t mean that if you have a degree we won’t work with you — we’re just not going to be impressed by that like some other firm may. We’ll break our thesis occasionally — for teams we know really well with great opportunities and for deep tech plays (we make a few deep tech investments every year) — but, ceteris paribus, we’ll focus on working with those outside of traditional, tracked institutions.
"""

# %%
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

from asgiref.sync import sync_to_async
from prelo.models import PitchDeck
from concurrent.futures import ThreadPoolExecutor


combined = ""
deck = PitchDeck.objects.get(id=27)


for slide in deck.slides.order_by("order"):
    if slide.order != 17:
        combined += f"Page {slide.order}:\n{slide.content}"

# %%
from decouple import config
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers.openai_functions import JsonKeyOutputFunctionsParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers.openai_functions import JsonOutputFunctionsParser, JsonKeyOutputFunctionsParser

THESIS_MATCH = """ You are a thesis matching submind for an early stage investor.

Here's the thesis you are matching against: {thesis}

Here's the pitch deck you received: {deck}

Determine whether or not the thesis matches, and explain how it matches or why it does not.

"""

functions = [
    {
        "name": "match_thesis",
        "description": "determine whether a company matches an investor's thesis based on their pitch deck",
        "parameters": {
            "type": "object",
            "properties": {
                "matches": {
                    "type": "boolean",
                    "description": "Whether or not the company matches the investment thesis",
                },
                "reason": {
                    "type": "string",
                    "description": "Why the company outlined in the deck matches the thesis or why it does not"                    
                    
                },
            },
            "required": ["matches", "reason"],
        },
    },
    {
        "name": "can_I_help",
        "description": "decide whether or not you are able to respond to the request knowledgably",
        "parameters": {
            "type": "object",
            "properties": {
                "can_i_help": {
                    "type": "boolean",
                    "description": "am I able to help with this request",
                   
                   

                    
            },
        },
            "required": ["can_i_help"],
        },
    },
]



model = ChatOpenAI(
        model="gpt-4-turbo",
        openai_api_key=config("OPENAI_API_KEY"),
        model_kwargs={
            "extra_headers": {
                "Helicone-Auth": f"Bearer {config('HELICONE_API_KEY')}",
                "Helicone-Property-UUID": deck.uuid

            }
        },
        openai_api_base="https://oai.hconeai.com/v1",
    )
prompt = ChatPromptTemplate.from_template(THESIS_MATCH)
chain = prompt | model.bind(function_call={"name": "match_thesis"},
                            functions=functions) | JsonOutputFunctionsParser()
response = chain.invoke({"thesis": THESIS, "deck": combined})
print(f"{response}")
# Out:
# {'matches': True, 'reason': "The pitch deck presents a founder with a non-traditional background who has pursued an unconventional path in developing their business model. The narrative includes the founder's personal journey of being laid off, using severance to fund their startup, and facing rejections from investors, showcasing resilience and innovation without reliance on formal credentials. This aligns with 1517 Fund's thesis of supporting founders who are often overlooked by traditional investors due to their unconventional credentials or lack of formal education. The presentation also emphasizes the founder's unique skills and creative approach to solving problems, further fitting the thesis of backing founders outside of tracked institutions."}
